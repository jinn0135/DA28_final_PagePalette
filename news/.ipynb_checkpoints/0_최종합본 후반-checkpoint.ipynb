# %% [markdown]
# # 사용할 기사 선택하고, 메일링 데이터프레임 형식에 맞게 수정하기

# %%
now = datetime.now()
formatted_time = now.strftime("%Y-%m-%d_%p")
formatted_time = formatted_time.lower()


df = pd.read_csv(formatted_time+'.csv')
df = df.rename(columns={'URL':'link', '제목':'title', '본문':'desc', '토픽':'topic'})
df
# Out:
#                                                  link  wc  \
# 0   https://n.news.naver.com/mnews/article/015/000... NaN
# 1   https://n.news.naver.com/mnews/article/293/000... NaN
# 2   https://n.news.naver.com/mnews/article/092/000... NaN
# 3   https://n.news.naver.com/mnews/article/366/000... NaN
# 4              https://v.daum.net/v/20230703151615839 NaN
# 5              https://v.daum.net/v/20230703085307971 NaN
# 6   https://n.news.naver.com/mnews/article/003/001... NaN
# 7              https://v.daum.net/v/20230703091904889 NaN
# 8              https://v.daum.net/v/20230703104011763 NaN
# 9              https://v.daum.net/v/20230703091014595 NaN
# 10  https://n.news.naver.com/mnews/article/031/000... NaN
# 11             https://v.daum.net/v/20230703160035973 NaN
# 12  https://n.news.naver.com/mnews/article/138/000... NaN
# 13  https://n.news.naver.com/mnews/article/138/000... NaN
# 14  https://n.news.naver.com/mnews/article/138/000... NaN
#
#                                                  desc  \
# 0   한국 통신업 텔레 플레이 현상 곳곳 나타 나미 인상 국도 한국 통신업 피해 의식 정...
# 1   서울시 중구 위치 SKT 본사 SK 타워 SKT 제로 탄소 중립 선언 SK 텔레콤 ...
# 2   삼성전자 SK하이닉스 최고 경신 AI 확대 수혜 실적 개선 기대 반도체 주식 몰리 ...
# 3   경쟁 활성화 통신사 유치 수익 성규 산업 후보 거론 난색 미래 모바일 도전 선언 자...
# 4   스팀 여름 포스터 파격 일로 유명 전자 소프트웨어 유통 스팀 여름 일이 일한국 시간...
# 5   어플 라이드 티어 리얼 코리아 진행 지역 아동 대상 과학 교실 프로그램 어플 라이드...
# 6   5G 다이렉트 신규 출시 기존 요금 데이터 연말 프로모션 지니 뮤직 밀리 서재 무료...
# 7   왼쪽 부터 티스 바이오 최원우 로레알 그룹 바바라 라베 르노 AR AR OS 연구 ...
# 8   농심 레드 포스 배틀그라운드 모바일 창단 음으로 프로리그 시즌 우승 대전 스포츠 경...
# 9   최원우 왼쪽 티스 바이오 바바라 라베 르노 로레알 그룹 연구 혁신 부문 수석 부사 ...
# 10  과기정통부 천억 공공 SW 사업 대기업 허용 개선 방안 업계 공공 SW 품질 저하 ...
# 11  대전광역시 협약 선도 과제 시범 운영 로지 디넷 코리아 박수 디지털 플랫폼 정부 전...
# 12  대기업 문호 품질 저하 중소 중견 문제 서울 중구 공공 소프트웨어 사업 대기업 제한...
# 13  식물 상임 전락 과방 업계 정당 대가 실현 먼저 서울 중구 공공 소프트웨어 사업 대...
# 14  서울 중구 공공 소프트웨어 사업 제한 제도 개선 토론회 디지털 데일 디지털 데일 이...
#
#                                                    원본  \
# 0   [기로에선 한국 통신업계 ②]\n‘텔레플레이션’ 현상 곳곳서 나타나\n미국 1·2위...
# 1   서울시 중구에 위치한 SKT 본사 'SK-T타워'. (사진=SKT)\n2050년 넷...
# 2   삼성전자·SK하이닉스, 52주 최고가 경신…AI 확대 수혜·실적 개선 기대↑\n반도...
# 3   시장 경쟁 활성화 위한 제4 통신사 유치 조용\n‘낮은 수익성·규제산업’ 후보 거론...
# 4    ‘스팀’의 여름 세일 포스터.\n\n파격적인 세일로 유명한 전자 소프트웨어 유통망...
# 5   어플라이드 머티어리얼즈 코리아가 진행하는 지역 아동 대상 과학교실 프로그램. /어플...
# 6   5G 다이렉트 신규 5종 출시… 기존 3종 요금제 데이터 늘려\n연말까지 프로모션으...
# 7   (사진 왼쪽부터) 큐티스바이오 최원우 대표, 로레알 그룹 바바라 라베르노스(Barb...
# 8   농심 레드포스 ‘배틀그라운드 모바일’ 팀이 창단 후 처음으로 프로리그 ‘PMPS 2...
# 9   최원우(왼쪽부터) 큐티스바이오 대표, 바바라 라베르노스 로레알 그룹 연구혁신·기술부...
# 10  과기정통부, 1천억 공공SW사업 대기업 참여 허용 등 개선방안 추진\n업계는 공공S...
# 11  대전광역시와 협약...디플정 선도과제 시범 운영키로\n(지디넷코리아=박수형 기자)디...
# 12  "대기업에 문호 더 열어야" vs "품질저하 중소·중견만의 문제 아냐"\n6월 30...
# 13  식물 상임위 전락한 과방위…업계 "정당대가 실현 먼저 이뤄져야"\n6월 30일 서울...
# 14  30일 서울 중구에서 공공 소프트웨어 사업 참여제한 제도개선 토론회가 열렸다. [ⓒ...
#
#                                             title topic
# 0   "앉아서 돈 번다" 눈총…물가 오를 때마다 매 맞는 통신3사 [정지은의 산업노트]   통신사
# 1       '2050 넷제로' SKT, 2022년 온실가스·용수사용량 더 늘었다…왜?   통신사
# 2                         반도체株에 몰린 돈…상반기에만 10兆 넘어   통신사
# 3       ‘제4 통신사’ 유치 이번에는… 정부, 통신시장 경쟁 활성화 방안 들어갈까   통신사
# 4                  ‘스팀’ 여름 할인 돌아와… ‘데이브 더 다이버’ 포함   통신사
# 5   어플라이드 머티어리얼즈 코리아, 지역 아동 대상 과학교실 프로그램 3년 연속 지원    게임
# 6             KT 온라인 전용 요금제도 결합할인 혜택 준다…'다이렉트' 개편    게임
# 7               카카오헬스-로레알-큐티스바이오, 정밀 뷰티 솔루션 개발 협업    게임
# 8              농심, 배그 모바일 프로대회 ‘PMPS 2023’ 시즌2 우승    게임
# 9       카카오헬스케어, 로레알 그룹·큐티스바이오와 `정밀 뷰티 솔루션` 개발 맞손    게임
# 10        [IT돋보기] 공공SW 대기업 참여보다 시급한 것은 "사업대가 현실화"  공공SW
# 11                   디지털플랫폼정부 비전, 중앙정부 넘어 지방으로 확산  공공SW
# 12                    공공SW사업에 대기업 뛰어든다?…업계 갈등 평행선  공공SW
# 13            평행선 달리는 '공공 SW 대기업 참여제한'…연내 입법 가능할까  공공SW
# 14  공공SW 대기업 참여 완화, 책임 강화된 주사업자…사업 수행 난도는 더 어려워져?  공공SW

# %% [markdown]
# # 워드클라우드 만들기

# %%
# 설정
width = 580
height = 338
max_words=30
mask = cv2.imread('./image/circle.png')
mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)

# %%
# 첫번째 토픽 워드클라우드
topic = input('토픽을 입력해주세요.')

text = ' '.join(df[df['topic']==topic]['desc'])
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf', width=width, height=height, max_words=max_words,
                      background_color='white', collocations=False, prefer_horizontal=1, mask=mask).generate(text)
plt.figure(figsize=(width/100, height/100))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# save
image = wordcloud.to_image()
image.save(formatted_time+'_'+topic+'.jpg')

# %%
# 두번째 토픽 워드클라우드
topic = input('토픽을 입력해주세요.')

text = ' '.join(df[df['topic']==topic]['desc'])
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf', width=width, height=height, max_words=max_words,
                      background_color='white', collocations=False, prefer_horizontal=1, mask=mask).generate(text)
plt.figure(figsize=(width/100, height/100))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# save
image = wordcloud.to_image()
image.save(formatted_time+'_'+topic+'.jpg')

# %%
# 세번째 토픽 워드클라우드
topic = input('토픽을 입력해주세요.')

text = ' '.join(df[df['topic']==topic]['desc'])
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf', width=width, height=height, max_words=max_words,
                      background_color='white', collocations=False, prefer_horizontal=1, mask=mask).generate(text)
plt.figure(figsize=(width/100, height/100))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# save
image = wordcloud.to_image()
image.save(formatted_time+'_'+topic+'.jpg')

# %% [markdown]
# # GPT 요약 컬럼 추가하기
