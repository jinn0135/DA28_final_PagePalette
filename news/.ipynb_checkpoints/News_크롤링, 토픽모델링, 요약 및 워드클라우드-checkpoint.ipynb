# %% [markdown]
# # import

# %%
# data handling
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
import re
import json
from urllib.parse import quote

# crawling
import requests
import selenium
from selenium import webdriver
from bs4 import BeautifulSoup

# time control
from time import sleep
from datetime import datetime, date, timedelta

# NLP
import re
import ckonlpy
from ckonlpy.tag import Twitter
import gensim
from gensim import corpora
from gensim.models import CoherenceModel
from gensim.models import LdaModel
from gensim.utils import simple_preprocess
import openai

# NLP Visualization
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
from wordcloud import WordCloud
import cv2


# customized functions
from news_utils import *
from news_crawling import *
from news_utils import *
from news_words import *
from news_summarize import *

# utils
from tqdm import tqdm
import os

import warnings # FutureWarning 안보이게
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %% [markdown]
# # 다음 뉴스 크롤링

# %%
prepared_urls = get_urls_daum(hidden_window=False)

df_daum = pd.DataFrame({'URL':prepared_urls, '신문사':np.nan, '기자명':np.nan, '제목':np.nan, '본문':np.nan,
                   '날짜':np.nan, '연':np.nan, '월':np.nan, '일':np.nan, '요일':np.nan})

df_daum = news_crawler_daum(df_daum)
display(df_daum.head(3))
display(df_daum.tail(3))
# Out:
# An exception occurred: Message:
# 100%|██████████| 1713/1713 [20:19<00:00,  1.40it/s]
#                                       URL   신문사  기자명  \
# 0  https://v.daum.net/v/20230704230603511  IT동아  김영우
# 1  https://v.daum.net/v/20230704223246303   게임톡  홍수민
# 2  https://v.daum.net/v/20230704222009179  연합뉴스  김주환
#
#                                        제목  \
# 0         [IT애정남] 취미용 영상 편집 위한 노트북, 골라주세요
# 1               금강선 복귀 "솔직한 소통으로 민심 되돌렸다"
# 2  '로스트아크' 금강선 CCO "중국 현지화, 국내 영향 없게 할 것"
#
#                                                   본문         날짜     연  월  일  \
# 0  [IT동아 김영우 기자] IT 전반에 관한 의문, 혹은 제품 및 서비스의 선택에 고... 2023-07-04  2023  7  4
# 1  로스트아크 긴급 방송, 최근 불거진 이슈 설명하고 향후 방향 제시\n- 금강선 스마... 2023-07-04  2023  7  4
# 2  '중국 검열판 적용' 논란에 사과…"당분간 CCO직 내려놓고 디렉터로서 소통"\n라... 2023-07-04  2023  7  4
#
#    요일
# 0   1
# 1   1
# 2   1
#                                          URL   신문사  기자명  \
# 1710  https://v.daum.net/v/20230705000345007  중앙일보   입력
# 1711  https://v.daum.net/v/20230705000335999  중앙일보   입력
# 1712  https://v.daum.net/v/20230705000021920   더팩트  최문정
#
#                                                  제목  \
# 1710                            [사진] 스타트업이 만든 자율비행체
# 1711  [Biz & Now] KT, 새 대표 후보자 12일까지 모집…‘공모+추천’ 투트랙
# 1712             "바닥 찍고 반등 시작"…메모리 업황 개선에 삼성·SK 웃을까
#
#                                                      본문         날짜     연  월  \
# 1710  스타트업이 만든 자율비행체\n국내 스타트업인 디스이즈엔지니어링(TIE)의 홍유정 대... 2023-07-05  2023  7
# 1711  KT가 오는 12일까지 차기 대표이사 후보자를 공개 모집한다. KT는 지난 3일 사... 2023-07-05  2023  7
# 1712  반도체 '실적 풍향계' 마이크론, 시장 예상치 웃돈 실적 발표\n6월 D램 가격 하... 2023-07-05  2023  7
#
#       일  요일
# 1710  5   2
# 1711  5   2
# 1712  5   2

# %% [markdown]
# # 네이버 뉴스 크롤링

# %%
# 네이버 IT뉴스 게시판에서 근 24시간에 해당하는 페이지 범위 설정
pages = page_lists(endpage=20)

# get_urls함수에 게시판 링크를 입력해 각 뉴스의 URL 저장
prepared_urls = get_urls_naver(pages=pages, hidden_window=True, verbose=False)

# 기사를 담을 데이터프레임 생성

df_naver = pd.DataFrame({'URL':prepared_urls, '신문사':np.nan, '기자명':np.nan, '제목':np.nan, '본문':np.nan,
                   '날짜':np.nan, '연':np.nan, '월':np.nan, '일':np.nan, '요일':np.nan})

# 각 네이버 기사에서 필요한 정보 스크래핑하여 데이터프레임에 적재
df_naver = news_crawler_naver(df_naver)
display(df_naver.head(3))
display(df_naver.tail(3))
# Out:
# 중복 제거 전 URL 수 : 414
# 중복 제거 후 URL 수 : 414
# 100%|██████████| 414/414 [06:23<00:00,  1.08it/s]
#                                                  URL   신문사  기자명  \
# 0  https://n.news.naver.com/mnews/article/001/001...  연합뉴스  조성미
# 1  https://n.news.naver.com/mnews/article/030/000...  전자신문  김명희
# 2  https://n.news.naver.com/mnews/article/030/000...  전자신문  김지선
#
#                                      제목  \
# 0  KT-과기정통부, 'AI 대학원 챌린지'로 실무형 AI 인재 발굴
# 1     뤼이드, 브라질 공교육에 AI 교육 솔루션 공급 MOU 체결
# 2           공공 앱·웹사이트, 사용자인 국민이 직접 평가한다
#
#                                                   본문         날짜     연  월  일  \
# 0  (서울=연합뉴스) 조성미 기자 = KT는 과학기술정보통신부와 인공지능(AI) 개발 ... 2023-07-05  2023  7  5
# 1  브라질 파라나주 주정부청사에서 진행된 뤼이드와 셀레파의 업무협약(MOU) 체결 사진... 2023-07-05  2023  7  5
# 2  국민이 공공 애플리케이션(앱)과 웹사이트를 평가하는 '국민평가제'가 시행된다.\n\... 2023-07-05  2023  7  5
#
#    요일
# 0   2
# 1   2
# 2   2
#                                                    URL     신문사  기자명  \
# 229  https://n.news.naver.com/mnews/article/031/000...  아이뉴스24  정종오
# 230  https://n.news.naver.com/mnews/article/001/001...    연합뉴스  김용태
# 231  https://n.news.naver.com/mnews/article/014/000...  파이낸셜뉴스  구자윤
#
#                                        제목  \
# 229  [의사과학자 길 걷다] UNIST-울산대의대 "제대로 키워보겠다"
# 230      UNIST·울산대 의대, 의과학자 양성 공동 교육과정 확정
# 231       "아, 진작 할 걸.. " 알뜰폰 0원 요금제 사실상 끝
#
#                                                     본문         날짜     연  월  일  \
# 229  UNIST·울산대 의대, 학사과정생부터 전주기적 커리큘럼 만들어\n의사과학자 육성에... 2023-07-04  2023  7  4
# 230  UNIST에 의과학 AI 등 7개 과목 개설…9월부터 수강 시작\n\n\nUNIST... 2023-07-04  2023  7  4
# 231  알뜰폰 정보 제공 사이트 '알뜰폰허브'에서 0원 요금제로 검색한 결과 과거처럼 3M... 2023-07-04  2023  7  4
#
#      요일
# 229   1
# 230   1
# 231   1

# %% [markdown]
# # 네이버 뉴스와 다음 뉴스를 Merge 데이터프레임 만들기

# %%
df = pd.concat([df_naver, df_daum], axis=0)
df = df.reset_index(drop=True)
df
# Out:
#                                                     URL     신문사  기자명  \
# 0     https://n.news.naver.com/mnews/article/001/001...    연합뉴스  조성미
# 1     https://n.news.naver.com/mnews/article/030/000...    전자신문  김명희
# 2     https://n.news.naver.com/mnews/article/030/000...    전자신문  김지선
# 3     https://n.news.naver.com/mnews/article/138/000...  디지털데일리  이나연
# 4     https://n.news.naver.com/mnews/article/001/001...    연합뉴스  조성미
# ...                                                 ...     ...  ...
# 1185             https://v.daum.net/v/20230705002504227    쿠키뉴스  차종관
# 1186             https://v.daum.net/v/20230705000622123  강원도민일보  김덕형
# 1187             https://v.daum.net/v/20230705000345007    중앙일보   입력
# 1188             https://v.daum.net/v/20230705000335999    중앙일보   입력
# 1189             https://v.daum.net/v/20230705000021920     더팩트  최문정
#
#                                                  제목  \
# 0              KT-과기정통부, 'AI 대학원 챌린지'로 실무형 AI 인재 발굴
# 1                 뤼이드, 브라질 공교육에 AI 교육 솔루션 공급 MOU 체결
# 2                       공공 앱·웹사이트, 사용자인 국민이 직접 평가한다
# 3              네이버D2SF, 데이터 생성·비식별화 스타트업 ‘큐빅’ 신규 투자
# 4              정부 "기업 AI 윤리 확보 위해 가이드라인 제시·검증체계 지원"
# ...                                             ...
# 1185   금강선, ‘로스트아크’ 디렉터로 임시 복귀…“중국 현지화, 국내 악영향 없도록”
# 1186                      “전기요금 차등제 추진 동해안 기업유치 기회”
# 1187                            [사진] 스타트업이 만든 자율비행체
# 1188  [Biz & Now] KT, 새 대표 후보자 12일까지 모집…‘공모+추천’ 투트랙
# 1189             "바닥 찍고 반등 시작"…메모리 업황 개선에 삼성·SK 웃을까
#
#                                                      본문         날짜     연  월  \
# 0     (서울=연합뉴스) 조성미 기자 = KT는 과학기술정보통신부와 인공지능(AI) 개발 ... 2023-07-05  2023  7
# 1     브라질 파라나주 주정부청사에서 진행된 뤼이드와 셀레파의 업무협약(MOU) 체결 사진... 2023-07-05  2023  7
# 2     국민이 공공 애플리케이션(앱)과 웹사이트를 평가하는 '국민평가제'가 시행된다.\n\... 2023-07-05  2023  7
# 3     [ⓒ 네이버D2SF]\n\n\n[디지털데일리 이나연 기자] 데이터에 노이즈를 주입해... 2023-07-05  2023  7
# 4     제2차 인공지능 윤리정책 포럼…신뢰성 담보 AI 활용 촉진 논의\n\n\n(서울=연... 2023-07-05  2023  7
# ...                                                 ...        ...   ... ..
# 1185  금강선 전 디렉터가 ‘운명의 빛’ 트레일러의 ‘붉은 달’ 일러스트 관련 의혹을 해명... 2023-07-05  2023  7
# 1186  강원연구원 기업천국 세미나\n▲ 강원연구원은 4일 연구원 민주홀에서 현진권 원장 주... 2023-07-05  2023  7
# 1187  스타트업이 만든 자율비행체\n국내 스타트업인 디스이즈엔지니어링(TIE)의 홍유정 대... 2023-07-05  2023  7
# 1188  KT가 오는 12일까지 차기 대표이사 후보자를 공개 모집한다. KT는 지난 3일 사... 2023-07-05  2023  7
# 1189  반도체 '실적 풍향계' 마이크론, 시장 예상치 웃돈 실적 발표\n6월 D램 가격 하... 2023-07-05  2023  7
#
#       일  요일
# 0     5   2
# 1     5   2
# 2     5   2
# 3     5   2
# 4     5   2
# ...  ..  ..
# 1185  5   2
# 1186  5   2
# 1187  5   2
# 1188  5   2
# 1189  5   2
#
# [1190 rows x 10 columns]

# %% [markdown]
# # 텍스트 전처리

# %%
# raw text와 processed text를 비교하기 위해 copy
df_preprocess = df.copy()
df_preprocess['본문'] = df_preprocess['본문'].str.upper() # 전부 대문자로 변경

# twitter 객체에 Noun 단어 adding
twitter = Twitter()

# 사용자 정의 명사 지정 리스트 받기
add_words = get_addwords()
# 불용어 리스트 받기
stop_words = get_stopwords()

for noun in add_words:
    twitter.add_dictionary(noun, 'Noun')

# re와 ckonlpy로 전처리
articles = df_preprocess['본문']

# 본문 Seriese객체에서 index 받아오기
# 기사의 건수(약 1400건)만큼 iter
for idx in tqdm(range(len(articles))): 
    # re로 기본적인 전처리
    text = articles[idx]
    to_remove = '[\n,@\'()‘“”’%./■△\"·]+'
    text = re.sub(to_remove, '', text)
    
    # ckonlpy로 ' '로 구분된 string형태의 corpus 생성
    contents =''
    for temp_word in twitter.nouns(text):
        # 한글자와 불용어 제외
        if (len(temp_word) > 1)&(temp_word not in stop_words):
            contents = contents + ' ' + temp_word
    
    # 전처리를 거친 corpus를 df_preprocess의 본문에 저장
    df_preprocess.loc[idx, '본문'] = contents.strip()

# 중복 제거
df_preprocess = df_preprocess.drop_duplicates(subset=['본문'])
    
######################################## Check result
sleep(2)
print("전처리 전 :")
print("*"*50)
display(df.head(3))
display(df.tail(3))
print('\n\n')
print("전처리 후 :")
print("*"*50)
display(df_preprocess.head(3))
display(df_preprocess.tail(3))
########################################
# Out:
# C:\Users\kyooo\anaconda3\envs\final\lib\site-packages\konlpy\tag\_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# 100%|██████████| 1190/1190 [00:36<00:00, 32.84it/s]
# 전처리 전 :
# **************************************************
#                                                  URL   신문사  기자명  \
# 0  https://n.news.naver.com/mnews/article/001/001...  연합뉴스  조성미
# 1  https://n.news.naver.com/mnews/article/030/000...  전자신문  김명희
# 2  https://n.news.naver.com/mnews/article/030/000...  전자신문  김지선
#
#                                      제목  \
# 0  KT-과기정통부, 'AI 대학원 챌린지'로 실무형 AI 인재 발굴
# 1     뤼이드, 브라질 공교육에 AI 교육 솔루션 공급 MOU 체결
# 2           공공 앱·웹사이트, 사용자인 국민이 직접 평가한다
#
#                                                   본문         날짜     연  월  일  \
# 0  (서울=연합뉴스) 조성미 기자 = KT는 과학기술정보통신부와 인공지능(AI) 개발 ... 2023-07-05  2023  7  5
# 1  브라질 파라나주 주정부청사에서 진행된 뤼이드와 셀레파의 업무협약(MOU) 체결 사진... 2023-07-05  2023  7  5
# 2  국민이 공공 애플리케이션(앱)과 웹사이트를 평가하는 '국민평가제'가 시행된다.\n\... 2023-07-05  2023  7  5
#
#    요일
# 0   2
# 1   2
# 2   2
#                                          URL   신문사  기자명  \
# 1187  https://v.daum.net/v/20230705000345007  중앙일보   입력
# 1188  https://v.daum.net/v/20230705000335999  중앙일보   입력
# 1189  https://v.daum.net/v/20230705000021920   더팩트  최문정
#
#                                                  제목  \
# 1187                            [사진] 스타트업이 만든 자율비행체
# 1188  [Biz & Now] KT, 새 대표 후보자 12일까지 모집…‘공모+추천’ 투트랙
# 1189             "바닥 찍고 반등 시작"…메모리 업황 개선에 삼성·SK 웃을까
#
#                                                      본문         날짜     연  월  \
# 1187  스타트업이 만든 자율비행체\n국내 스타트업인 디스이즈엔지니어링(TIE)의 홍유정 대... 2023-07-05  2023  7
# 1188  KT가 오는 12일까지 차기 대표이사 후보자를 공개 모집한다. KT는 지난 3일 사... 2023-07-05  2023  7
# 1189  반도체 '실적 풍향계' 마이크론, 시장 예상치 웃돈 실적 발표\n6월 D램 가격 하... 2023-07-05  2023  7
#
#       일  요일
# 1187  5   2
# 1188  5   2
# 1189  5   2
# 전처리 후 :
# **************************************************
#                                                  URL   신문사  기자명  \
# 0  https://n.news.naver.com/mnews/article/001/001...  연합뉴스  조성미
# 1  https://n.news.naver.com/mnews/article/030/000...  전자신문  김명희
# 2  https://n.news.naver.com/mnews/article/030/000...  전자신문  김지선
#
#                                      제목  \
# 0  KT-과기정통부, 'AI 대학원 챌린지'로 실무형 AI 인재 발굴
# 1     뤼이드, 브라질 공교육에 AI 교육 솔루션 공급 MOU 체결
# 2           공공 앱·웹사이트, 사용자인 국민이 직접 평가한다
#
#                                                   본문         날짜     연  월  일  \
# 0  서울 연합뉴스 조성미 KT 과학기술정보통신부 인공지능 AI 개발 대회 AI 대학원 ... 2023-07-05  2023  7  5
# 1  브라질 파라나 정부 청사 진행 이드 셀레 파의 업무 협약 MOU 체결 왼쪽 이드 준... 2023-07-05  2023  7  5
# 2  국민 공공 애플리케이션 웹사이트 평가 국민 평가 시행 행정안전부 디지털 플랫폼 정부... 2023-07-05  2023  7  5
#
#    요일
# 0   2
# 1   2
# 2   2
#                                          URL   신문사  기자명  \
# 1187  https://v.daum.net/v/20230705000345007  중앙일보   입력
# 1188  https://v.daum.net/v/20230705000335999  중앙일보   입력
# 1189  https://v.daum.net/v/20230705000021920   더팩트  최문정
#
#                                                  제목  \
# 1187                            [사진] 스타트업이 만든 자율비행체
# 1188  [Biz & Now] KT, 새 대표 후보자 12일까지 모집…‘공모+추천’ 투트랙
# 1189             "바닥 찍고 반등 시작"…메모리 업황 개선에 삼성·SK 웃을까
#
#                                                      본문         날짜     연  월  \
# 1187  스타트업 자율 비행 국내 스타트업 디스 이즈 엔지니어링 홍유 기자간담회 고속 자율 ... 2023-07-05  2023  7
# 1188  KT 차기 대표이사 후보자 공개 모집 KT 사외이사 전원 구성 이사 후보 추천 위원... 2023-07-05  2023  7
# 1189  반도체 실적 풍향계 마이크론 예상 웃돈 실적 발표 가격 하락 낸드 플래시 정세 지난... 2023-07-05  2023  7
#
#       일  요일
# 1187  5   2
# 1188  5   2
# 1189  5   2

# %% [markdown]
# # 토픽 모델링 및 Topic Num 최적화

# %%
# 리스트 내 리스트 형태로 저장
preprocessed_articles = [article.split(' ') for article in articles]

# %%
# corpora.Dictionary
dictionary = corpora.Dictionary(preprocessed_articles)
dictionary.filter_extremes(no_below=10, no_above=0.8)

corpus = [dictionary.doc2bow(article) for article in preprocessed_articles]
texts = [preprocessed_articles[idx] for idx in range(len(corpus))]

# %%
PARAM = {
    'RANGES':15,
    'PASSES':50,
    'ITER':100,
    'COHERENCE_METRIC':'c_v',
}

# %%
# 3개부터 최대 15개까지의 토픽 수를 비교하며 정합도 점수 기록
news_coherence_scores = []

for i in tqdm(range(3, PARAM['RANGES']+1), desc="Operating All Topic Ranges"):
    model = LdaModel(corpus=corpus, num_topics=i, id2word=dictionary, passes=PARAM['PASSES'],
                     iterations=PARAM['ITER'])
    coherence_model = CoherenceModel(model=model, texts=texts, corpus=corpus, dictionary=dictionary, coherence=PARAM['COHERENCE_METRIC'])
    coherence_lda = coherence_model.get_coherence()
    news_coherence_scores.append(coherence_lda)
# Out:
# Operating All Topic Ranges: 100%|██████████| 13/13 [16:05<00:00, 74.23s/it]

# %%
k = [i for i in range(3, PARAM['RANGES']+1)]
x = np.array(k)
y = np.array(news_coherence_scores)
plt.figure(figsize=(10, 5))
plt.plot(x, y)
plt.xlabel("Number Of Topic(2-"+str(PARAM['RANGES'])+")")
plt.ylabel('Coherence Score')
plt.show()

# %% [markdown]
# # Topic Num이 최적화된 모델

# %%
find_best = np.array([news_coherence_scores])
Best_Num_Of_Topic = int(np.where(y==find_best.max())[0][0]+3)
print("최적의 토픽 수 :", Best_Num_Of_Topic)
print("정합도 점수 :", round(find_best.max(), 4))
# Out:
# 최적의 토픽 수 : 6
# 정합도 점수 : 0.5023

# %%
num_topics = Best_Num_Of_Topic
lda_model = LdaModel(corpus, num_topics, dictionary, passes=PARAM['PASSES'], iterations=PARAM['ITER'])#, alpha=PARAM['ALPHA'], eta=PARAM['ETA'])

# %%
# LDA 시각화
pyLDAvis.enable_notebook()
p = pyLDAvis.gensim_models.prepare(topic_model=lda_model, corpus=corpus, dictionary=dictionary)
pyLDAvis.display(p)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el376821518146786727554203562" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el376821518146786727554203562_data = {"mdsDat": {"x": [-0.08217060763111426, -0.09935429099342946, -0.07747485769584891, -0.08265024664428287, 0.27510371672586126, 0.06654628623881477], "y": [0.04529406631974691, -0.035043973024043884, -0.07306674127189752, 0.16356117724351074, 0.0709722130901658, -0.17171674235748197], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [23.421161411920032, 22.741085717669243, 16.38727724159948, 14.48709123070917, 11.790263406594322, 11.17312099150775]}, "tinfo": {"Term": ["\uc218\uc2e0\ub8cc", "\ubc18\ub3c4\uccb4", "\uac8c\uc784", "\uc9d5\uc218", "AI", "\ubc29\uc1a1", "\uc624\uc5fc\uc218", "\uc2dc\ud589", "\ubc29\ub958", "\uc0bc\uc131\uc804\uc790", "\ubc29\ud1b5\uc704", "\uc77c\ubcf8", "\uad6d\ubbfc", "\ubcf4\uace0\uc11c", "\ub370\uc774\ud130", "\uad11\uace0", "\uc6b0\uc8fc", "\ubd84\ub9ac", "\uc704\uc6d0\ud68c", "\ud68c\uc758", "\uc704\uc6d0", "KT", "\ud6c4\ucfe0\uc2dc\ub9c8", "\uac1c\uc815\uc548", "\ub098\ub178", "\uc790\uc6d0", "\uc815\ubd80", "\uac1c\ubc1c", "\uc694\uae08", "TV", "\ud30c\uc6b4\ub4dc\ub9ac", "\ub098\ub178", "SK\ud558\uc774\ub2c9\uc2a4", "\ubcf5\uc9c0", "\uacfc\ubaa9", "\uc544\uc774\ud15c", "\ud339\ub9ac\uc2a4", "\ubb34\uc5ed", "\uac08\ub968", "\ubc18\ub3c4\uccb4", "\ub125\uc2a8", "\uc120\uc218", "MMORPG", "\uc778\uce58", "\ub178\ud2b8\ubd81", "\uc131\uacfc\uae09", "\ucef4\ud22c\uc2a4", "\uc6e8\uc774\ud37c", "\ud328\ud0a4\uc9d5", "\uac8c\ub974\ub9c8\ub284", "\uc138\uacc4\uad00", "\ub9c8\uc774\ud06c\ub860", "\uc758\uc0ac\uacfc\ud559", "\uad50\uacfc\ubaa9", "\ucee4\ub125\ud2b8", "\uc0c1\uc790", "\uc5b4\ube44\uc2a4", "\ubcf8\uae09", "\uc758\uacfc\ub300\ud559", "\uc561\uc158", "\ubd80\ud488", "\uba54\ubaa8\ub9ac", "\ub514\uc2a4\ud50c\ub808\uc774", "\uc0bc\uc131\uc804\uc790", "\uc2e4\uc801", "\uac8c\uc784", "\uc804\uae30\ucc28", "\ubc95\uc778", "\uc591\uc0b0", "\uacf5\uc815", "\ubd84\uae30", "\uc560\ud50c", "\uc911\uad6d", "\uc0bc\uc131", "\uc774\ubca4\ud2b8", "\uc6b8\uc0b0", "OLED", "\uc81c\uc870", "\uc0dd\uc0b0", "\ub9e4\ucd9c", "\uc2a4\ub9c8\ud2b8\ud3f0", "\ubc30\ud130\ub9ac", "\uc218\ucd9c", "\uc62c\ud574", "\uad6d\ub0b4", "\ub2e4\uc591", "\uc138\ub300", "\uc5c5\uacc4", "\ud22c\uc790", "\uc9c0\ub09c\ud574", "\uac1c\ubc1c", "\uc9c4\ud589", "\uc804\ub7b5", "\uae00\ub85c\ubc8c", "\uc0b0\uc5c5", "\uc0ac\uc5c5", "\uba74\uc11c", "\uc138\uacc4", "AI", "\ucd9c\uc2dc", "\uae08\uc9c0", "\uce58\ub8cc", "\uc720\uc804\uc790", "\uc2e0\uc57d", "\uc2a4\ub808\ub4dc", "\uc9c8\ud658", "AWS", "\ud06c\ub9ac\uc2a4", "\ud050\ube45", "\ub7ec\ub2dd", "\ub2e8\ubc31\uc9c8", "\uc57d\ubb3c", "\ucf54\uc5b4", "\ucf54\uc778", "\uc591\uadf9", "\uc544\ub9c8\uc874", "\ud654\uc774\uc790", "\ub098\ud2b8\ub968", "\uc800\ucee4\ubc84\uadf8", "\uc2a4\ucf00", "\ud504\ub77c\uc774\ubc84\uc2dc", "\uc804\ud574\uc9c8", "\ud0dc\uad6d", "\uba38\uc2e0", "\uc9c8\ubcd1", "\ucd08\uc18c", "\ud14c\ub77c", "\ud2b8\ub799", "\ud14c\ud06c\ub180\ub85c\uc9c0", "\uc0c1\uc7a5", "\uc81c\ud488\uad70", "\uc81c\uc57d", "\uba38\uc2a4\ud06c", "\uba54\ud0c0", "\ud074\ub77c\uc6b0\ub4dc", "\uc758\uc57d\ud488", "\ucf00\uc5b4", "\uc0ac\uc774\uc5b8\uc2a4", "\uc194\ub8e8\uc158", "\ubc14\uc774\uc624", "\ud2b8\uc704\ud130", "\uacc4\uc57d", "\ube44\uc988\ub2c8\uc2a4", "\uc2a4\ud0c0\ud2b8\uc5c5", "\ub370\uc774\ud130", "\ud50c\ub7ab\ud3fc", "\uac1c\ubc1c", "AR", "\ubb3c\uc9c8", "AI", "\ud559\uc2b5", "\uae00\ub85c\ubc8c", "\ubbf8\uad6d", "\uc5f0\uad6c", "\uae30\ubc18", "\ubd84\uc11d", "\uaddc\ubaa8", "\ud22c\uc790", "\ud65c\uc6a9", "\uc0ac\uc5c5", "\uc0dd\uc0b0", "\uacb0\uacfc", "\uc790\uc0ac", "\uc0ac\uc6a9", "\uad6d\ub0b4", "\uc9c4\ud589", "\uc131\uc7a5", "\uacc4\ud68d", "\ubb34\ub2e8", "\uc7ac\ubc30", "\uae08\uc9c0", "\uace0\uac1d", "\ud55c\uad6d", "\uc138\uacc4", "\uc2dc\uc138", "\uc9c0\uc9c8", "\uc2e0\uc6a9", "\ucf54\ud37c\ub808\uc774\uc158", "\ud638\ud154", "\ubcf4\uc548\uad00", "\uc784\uc6d0", "\uc784\uae30", "\ub2e4\uba38", "\uc6b0\uc8fc", "\uc0ac\uc678\uc774\uc0ac", "\uc0b0\ud559", "\uc0ac\uc774\ubc84", "\ucf54\uc624\ ...

# %% [markdown]
# # 각 토픽에 정합하는 기사 추출

# %%
# 각 문서에 대한 주제 분포 가져오기
document_topics = [lda_model.get_document_topics(doc) for doc in corpus]
# document_topics # 1382개

main_topic_list = []

for article_idx, article in enumerate(document_topics):
    max_score = 1e-8
    max_topic_num = -1e-8
    
    # 한 기사안에서 토픽 : 점수
    for topicnum, score in article:
        if score > max_score:
            max_score = score
            max_topic_num = topicnum
    #main_topic_list.append((str(max_topic_num+1)+'번토픽', max_score))
    main_topic_list.append((int(max_topic_num)+1, max_score))

main_topic_list
# Out:
# [(1, 0.66748524),
#  (2, 0.9935789),
#  (4, 0.99522585),
#  (2, 0.9944873),
#  (6, 0.5068793),
#  (6, 0.60147405),
#  (3, 0.9986519),
#  (2, 0.99322176),
#  (3, 0.9973739),
#  (5, 0.783135),
#  (4, 0.99752915),
#  (4, 0.6830685),
#  (1, 0.9950449),
#  (5, 0.91882926),
#  (5, 0.6108704),
#  (5, 0.99396694),
#  (3, 0.99702436),
#  (2, 0.99609876),
#  (2, 0.8020321),
#  (5, 0.996183),
#  (6, 0.38591596),
#  (5, 0.992882),
#  (3, 0.9987724),
#  (2, 0.85937953),
#  (3, 0.80945116),
#  (5, 0.99555546),
#  (6, 0.9898697),
#  (5, 0.9985017),
#  (5, 0.7850354),
#  (5, 0.56859004),
#  (3, 0.5598647),
#  (3, 0.998667),
#  (5, 0.37739143),
#  (5, 0.95302284),
#  (3, 0.3752344),
#  (2, 0.53815717),
#  (6, 0.91232026),
#  (5, 0.9918544),
#  (1, 0.8107784),
#  (2, 0.65697134),
#  (1, 0.63184154),
#  (4, 0.9959579),
#  (3, 0.9224122),
#  (5, 0.8133416),
#  (4, 0.75419396),
#  (3, 0.9975715),
#  (2, 0.82623714),
#  (3, 0.99756527),
#  (1, 0.5792753),
#  (2, 0.9974793),
#  (2, 0.98292255),
#  (2, 0.5805877),
#  (2, 0.97034454),
#  (3, 0.9972497),
#  (5, 0.9951895),
#  (6, 0.48079365),
#  (2, 0.866163),
#  (2, 0.52111685),
#  (3, 0.99661666),
#  (3, 0.99731886),
#  (3, 0.9900648),
#  (3, 0.996617),
#  (3, 0.9965717),
#  (1, 0.8952613),
#  (5, 0.99718934),
#  (3, 0.99605167),
#  (4, 0.99659324),
#  (2, 0.88783634),
#  (6, 0.9678873),
#  (4, 0.994702),
#  (5, 0.99527043),
#  (1, 0.99308443),
#  (2, 0.5691507),
#  (5, 0.5647906),
#  (1, 0.7691361),
#  (2, 0.94644374),
#  (2, 0.615007),
#  (4, 0.97030187),
#  (4, 0.5957299),
#  (5, 0.9108699),
#  (3, 0.9955116),
#  (1, 0.40197292),
#  (2, 0.9957248),
#  (5, 0.84636176),
#  (3, 0.9566059),
#  (3, 0.63159657),
#  (5, 0.9910713),
#  (6, 0.9563943),
#  (1, 0.99594826),
#  (3, 0.9948443),
#  (4, 0.8644047),
#  (4, 0.9941291),
#  (2, 0.9954971),
#  (5, 0.76159143),
#  (1, 0.6658019),
#  (1, 0.996587),
#  (2, 0.99719536),
#  (2, 0.55086136),
#  (5, 0.9943535),
#  (2, 0.85079354),
#  (2, 0.6830796),
#  (4, 0.9958492),
#  (6, 0.9969339),
#  (5, 0.80586165),
#  (2, 0.5278076),
#  (6, 0.9119251),
#  (6, 0.492653),
#  (2, 0.7288215),
#  (6, 0.7758806),
#  (3, 0.6156091),
#  (5, 0.91434056),
#  (1, 0.99736285),
#  (2, 0.814011),
#  (5, 0.5723305),
#  (6, 0.707676),
#  (3, 0.997505),
#  (2, 0.93021595),
#  (2, 0.99762416),
#  (1, 0.5985226),
#  (2, 0.6871134),
#  (2, 0.74971354),
#  (5, 0.5261515),
#  (1, 0.9946957),
#  (4, 0.53117245),
#  (1, 0.89857507),
#  (6, 0.52453977),
#  (2, 0.6511616),
#  (5, 0.9902575),
#  (4, 0.99423116),
#  (2, 0.85690445),
#  (6, 0.68167704),
#  (2, 0.99777085),
#  (5, 0.7957707),
#  (1, 0.99719554),
#  (2, 0.46238026),
#  (1, 0.5881945),
#  (2, 0.697317),
#  (3, 0.9981364),
#  (1, 0.6171457),
#  (5, 0.9971963),
#  (5, 0.7283236),
#  (1, 0.8150154),
#  (6, 0.73093396),
#  (2, 0.6198948),
#  (2, 0.5731522),
#  (6, 0.9958683),
#  (4, 0.9972545),
#  (1, 0.60189015),
#  (4, 0.9978885),
#  (4, 0.99768835),
#  (5, 0.95426005),
#  (2, 0.81855494),
#  (5, 0.90740997),
#  (6, 0.6346878),
#  (5, 0.99720216),
#  (3, 0.97904676),
#  (3, 0.9962743),
#  (3, 0.9964434),
#  (3, 0.99744517),
#  (5, 0.6612779),
#  (2, 0.4060656),
#  (3, 0.6453965),
#  (3, 0.8677597),
#  (6, 0.60722464),
#  (5, 0.48037213),
#  (6, 0.4924175),
#  (4, 0.9983335),
#  (4, 0.996867),
#  (6, 0.8950365),
#  (1, 0.7680361),
#  (2, 0.95173514),
#  (1, 0.99767625),
#  (5, 0.9968506),
#  (5, 0.99337894),
#  (6, 0.47092408),
#  (5, 0.7008971),
#  (4, 0.99588704),
#  (1, 0.53235435),
#  (6, 0.91868764),
#  (1, 0.5206601),
#  (2, 0.9969257),
#  (4, 0.5235247),
#  (3, 0.9970114),
#  (2, 0.99465543),
#  (2, 0.7496651),
#  (2, 0.77208847),
#  (1, 0.9957943),
#  (6, 0.579655),
#  (6, 0.99808687),
#  (2, 0.7658057),
#  (5, 0.8764128),
#  (5, 0.82231164),
#  (5, 0.91588855),
#  (5, 0.40666312),
#  (1, 0.9949198),
#  (3, 0.9976834),
#  (2, 0.9549206),
#  (5, 0.67515373),
#  (6, 0.3659552),
#  (6, 0.6412666),
#  (5, 0.6578157),
#  (3, 0.8975316),
#  (6, 0.47201228),
#  (5, 0.9494358),
#  (1, 0.9879851),
#  (3, 0.997221),
#  (4, 0.8092208),
#  (2, 0.9395308),
#  (5, 0.66225255),
#  (6, 0.9976006),
#  (5, 0.8848018),
#  (1, 0.9951855),
#  (6, 0.6999204),
#  (5, 0.9951773),
#  (4, 0.40054506),
#  (5, 0.92064446),
#  (5, 0.70153105),
#  (5, 0.48451075),
#  (2, 0.54619604),
#  (5, 0.8587259),
#  (2, 0.67716837),
#  (4, 0.9975077),
#  (4, 0.57256067),
#  (5, 0.64813226),
#  (5, 0.9966871),
#  (1, 0.42022967),
#  (5, 0.6962244),
#  (4, 0.8659477),
#  (6, 0.9963562),
#  (5, 0.70519465),
#  (5, 0.7418808),
#  (1, 0.9952445),
#  (5, 0.44107914),
#  (3, 0.64949715),
#  (3, 0.99652797),
#  (6, 0.4445495),
#  (5, 0.71686506),
#  (5, 0.99539083),
#  (2, 0.4042326),
#  (5, 0.65213996),
#  (3, 0.9939511),
#  (4, 0.9968187),
#  (2, 0.46863353),
#  (1, 0.49227566),
#  (5, 0.69108516),
#  (3, 0.6347226),
#  (5, 0.58437574),
#  (2, 0.995623),
#  (2, 0.5475316),
#  (5, 0.7969245),
#  (4, 0.99623865),
#  (6, 0.5240341),
#  (6, 0.61607176),
#  (1, 0.40409124),
#  (6, 0.9636512),
#  (5, 0.71537715),
#  (6, 0.37796134),
#  (2, 0.795635),
#  (6, 0.98990834),
#  (4, 0.9983468),
#  (4, 0.49664772),
#  (6, 0.43741235),
#  (2, 0.7006578),
#  (4, 0.99690145),
#  (6, 0.8980158),
#  (5, 0.40802535),
#  (2, 0.8306423),
#  (6, 0.9886846),
#  (1, 0.6339857),
#  (2, 0.7715831),
#  (5, 0.8206107),
#  (1, 0.77145565),
#  (6, 0.99519676),
#  (5, 0.6340434),
#  (2, 0.4247007),
#  (5, 0.6957869),
#  (6, 0.99624115),
#  (4, 0.9902011),
#  (2, 0.8359711),
#  (2, 0.6194598),
#  (6, 0.7287932),
#  (1, 0.53546405),
#  (2, 0.913978),
#  (2, 0.920188),
#  (2, 0.7730925),
#  (1, 0.91121507),
#  (2, 0.9598041),
#  (6, 0.66231143),
#  (2, 0.7091904),
#  (6, 0.99585474),
#  (5, 0.7071218),
#  (2, 0.6720371),
#  (1, 0.99770164),
#  (2, 0.99288815),
#  (5, 0.68181556),
#  (1, 0.99504775),
#  (5, 0.51459974),
#  (2, 0.6100256),
#  (2, 0.46177176),
#  (4, 0.67951477),
#  (4, 0.99476355),
#  (4, 0.26671344),
#  (5, 0.99694145),
#  (5, 0.9841),
#  (5, 0.85704154),
#  (5, 0.8825902),
#  (2, 0.5384142),
#  (6, 0.99384356),
#  (6, 0.43758214),
#  (5, 0.61707944),
#  (5, 0.76297295),
#  (4, 0.9960019),
#  (2, 0.7200975),
#  (1, 0.99013233),
#  (6, 0.9206947),
#  (5, 0.4993594),
#  (6, 0.9967861),
#  (1, 0.52916473),
#  (2, 0.99697),
#  (3, 0.9970722),
#  (4, 0.53615695),
#  (2, 0.9950928),
#  (1, 0.9947595),
#  (2, 0.89186245),
#  (2, 0.74707663),
#  (6, 0.990368),
#  (1, 0.9958966),
#  (1, 0.70797056),
#  (2, 0.79919875),
#  (6, 0.9911893),
#  (1, 0.57515144),
#  (5, 0.9455958),
#  (2, 0.64759105),
#  (4, 0.9974142),
#  (6, 0.5468544),
#  (6, 0.58094287),
#  (6, 0.99569225),
#  (5, 0.8744232),
#  (2, 0.37055674),
#  (6, 0.8804034),
#  (6, 0.9981249),
#  (2, 0.7710717),
#  (1, 0.7439177),
#  (2, 0.67970407),
#  (2, 0.5737502),
#  (1, 0.46430796),
#  (2, 0.83219284),
#  (5, 0.99742585),
#  (2, 0.48176795),
#  (5, 0.78879666),
#  (2, 0.41674897),
#  (5, 0.40235564),
#  (6, 0.99552554),
#  (2, 0.5801308),
#  (4, 0.6863681),
#  (5, 0.6947078),
#  (2, 0.45915502),
#  (1, 0.99520975),
#  (4, 0.9962998),
#  (2, 0.95410854),
#  (5, 0.98807603),
#  (4, 0.9695623),
#  (2, 0.99282223),
#  (5, 0.80507517),
#  (1, 0.5412559),
#  (6, 0.9937267),
#  (5, 0.8147988),
#  (4, 0.56151706),
#  (5, 0.9913473),
#  (4, 0.6762983),
#  (5, 0.88609225),
#  (5, 0.6136041),
#  (5, 0.7105001),
#  (5, 0.99167067),
#  (6, 0.64333546),
#  (5, 0.7398236),
#  (3, 0.88088906),
#  (4, 0.9711749),
#  (2, 0.62696207),
#  (4, 0.9160164),
#  (5, 0.9874389),
#  (2, 0.5771002),
#  (5, 0.8818028),
#  (5, 0.71445435),
#  (6, 0.61265725),
#  (2, 0.7238667),
#  (6, 0.4361164),
#  (6, 0.6456922),
#  (2, 0.5598782),
#  (4, 0.53480715),
#  (2, 0.8618325),
#  (1, 0.6446541),
#  (1, 0.98879254),
#  (5, 0.9961969),
#  (3, 0.99730015),
#  (5, 0.992886),
#  (5, 0.99420893),
#  (4, 0.99027133),
#  (2, 0.76132953),
#  (4, 0.80831736),
#  (2, 0.9377524),
#  (5, 0.3554236),
#  (5, 0.3932434),
#  (2, 0.7888035),
#  (2, 0.3966002),
#  (1, 0.6680947),
#  (5, 0.9599958),
#  (6, 0.8514252),
#  (5, 0.6564508),
#  (6, 0.99766064),
#  (5, 0.8189507),
#  (2, 0.61835456),
#  (6, 0.4688709),
#  (1, 0.68611157),
#  (2, 0.4843649),
#  (2, 0.57983696),
#  (2, 0.6576456),
#  (2, 0.40076146),
#  (1, 0.9955428),
#  (6, 0.7025746),
#  (1, 0.5196997),
#  (5, 0.92629087),
#  (5, 0.73213583),
#  (6, 0.6104596),
#  (2, 0.32655388),
#  (6, 0.4823817),
#  (5, 0.99116),
#  (5, 0.9953361),
#  (2, 0.80156577),
#  (6, 0.47925082),
#  (5, 0.9962727),
#  (5, 0.70018077),
#  (4, 0.3873921),
#  (2, 0.82673585),
#  (5, 0.45737493),
#  (2, 0.3988028),
#  (2, 0.55201316),
#  (1, 0.3330022),
#  (5, 0.9941598),
#  (6, 0.77328205),
#  (5, 0.6098593),
#  (4, 0.6440387),
#  (2, 0.67794),
#  (5, 0.99522895),
#  (5, 0.9975464),
#  (2, 0.67817557),
#  (5, 0.7398181),
#  (4, 0.99754333),
#  (1, 0.6207302),
#  (1, 0.7190699),
#  (2, 0.9144857),
#  (6, 0.97855526),
#  (2, 0.5228002),
#  (6, 0.41183892),
#  (2, 0.8448501),
#  (5, 0.40289447),
#  (2, 0.5066326),
#  (5, 0.5576455),
#  (2, 0.5070983),
#  (2, 0.92621523),
#  (2, 0.427111),
#  (1, 0.5415018),
#  (5, 0.9967626),
#  (4, 0.85881364),
#  (4, 0.57466894),
#  (6, 0.9964922),
#  (1, 0.4237234),
#  (2, 0.79333466),
#  (5, 0.64752126),
#  (4, 0.4606112),
#  (1, 0.6794504),
#  (5, 0.6934993),
#  (5, 0.69944966),
#  (5, 0.51203173),
#  (5, 0.5832938),
#  (5, 0.7306449),
#  (6, 0.99737644),
#  (6, 0.9549509),
#  (6, 0.8686851),
#  (1, 0.9953493),
#  (5, 0.9708289),
#  (1, 0.7156671),
#  (2, 0.5676688),
#  (2, 0.52778244),
#  (6, 0.9009514),
#  (6, 0.99747723),
#  (1, 0.6770702),
#  (6, 0.4323276),
#  (5, 0.5893685),
#  (2, 0.9899904),
#  (1, 0.67358035),
#  (3, 0.62019515),
#  (2, 0.8373755),
#  (5, 0.78773904),
#  (6, 0.38806584),
#  (4, 0.86823976),
#  (6, 0.5543403),
#  (4, 0.870804),
#  (2, 0.89501077),
#  (2, 0.50129133),
#  (4, 0.91122806),
#  (5, 0.8096129),
#  (6, 0.94766086),
#  (6, 0.48290765),
#  (5, 0.9919194),
#  (6, 0.88394034),
#  (5, 0.98990124),
#  (6, 0.5843459),
#  (4, 0.66726893),
#  (4, 0.598431),
#  (2, 0.36653212),
#  (4, 0.59598786),
#  (4, 0.7216441),
#  (6, 0.39454037),
#  (5, 0.99096787),
#  (6, 0.8622559),
#  (3, 0.99742967),
#  (2, 0.47563604),
#  (6, 0.4538595),
#  (2, 0.99228114),
#  (5, 0.9933282),
#  (2, 0.99385846),
#  (2, 0.8810844),
#  (5, 0.99603105),
#  (5, 0.599927),
#  (5, 0.78279775),
#  (2, 0.74997795),
#  (4, 0.9975646),
#  (5, 0.6465479),
#  (2, 0.9874624),
#  (3, 0.99308187),
#  (6, 0.9162321),
#  (6, 0.59518063),
#  (2, 0.65628475),
#  (4, 0.48974904),
#  (2, 0.88038886),
#  (6, 0.6856179),
#  (6, 0.993187),
#  (5, 0.69666463),
#  (5, 0.6209551),
#  (2, 0.49634713),
#  (2, 0.58667856),
#  (4, 0.519049),
#  (2, 0.51870686),
#  (5, 0.5644811),
#  (5, 0.99659497),
#  (5, 0.9772871),
#  (5, 0.97006327),
#  (5, 0.96775883),
#  (6, 0.5896134),
#  (2, 0.9462413),
#  (5, 0.6333884),
#  (1, 0.6841803),
#  (1, 0.7218379),
#  (6, 0.88659614),
#  (6, 0.55664694),
#  (4, 0.98552036),
#  (4, 0.98552),
#  (2, 0.49311045),
#  (5, 0.70103115),
#  (2, 0.73725826),
#  (5, 0.912229),
#  (5, 0.6990919),
#  (5, 0.6064488),
#  (1, 0.9760143),
#  (1, 0.976014),
#  (1, 0.9760076),
#  (6, 0.99609876),
#  (5, 0.9942516),
#  (5, 0.52983934),
#  (1, 0.9915557),
#  (3, 0.997084),
#  (2, 0.480318),
#  (2, 0.81248015),
#  (5, 0.6976883),
#  (1, 0.53798187),
#  (2, 0.99619263),
#  (6, 0.64769286),
#  (6, 0.598107),
#  (6, 0.59812975),
#  (5, 0.85003215),
#  (4, 0.99522156),
#  (6, 0.5570581),
#  (6, 0.5904574),
#  (6, 0.69130164),
#  (6, 0.6912855),
#  (6, 0.691313),
#  (6, 0.5852802),
#  (6, 0.6912911),
#  (4, 0.62153655),
#  (6, 0.59361315),
#  (6, 0.6913132),
#  (6, 0.6912843),
#  (1, 0.87634206),
#  (2, 0.82008547),
#  (6, 0.6912891),
#  (6, 0.5570586),
#  (6, 0.6913011),
#  (5, 0.99633247),
#  (5, 0.8434185),
#  (2, 0.7983115),
#  (5, 0.99142945),
#  (2, 0.4555659),
#  (5, 0.9952332),
#  (6, 0.69854623),
#  (2, 0.9120102),
#  (5, 0.97111315),
#  (6, 0.382126),
#  (5, 0.9738117),
#  (5, 0.5298576),
#  (5, 0.97533274),
#  (5, 0.9737011),
#  (5, 0.9736951),
#  (5, 0.6995333),
#  (5, 0.97368264),
#  (5, 0.50860023),
#  (5, 0.9915112),
#  (5, 0.56224006),
#  (2, 0.79216707),
#  (6, 0.40855289),
#  (5, 0.9932204),
#  (1, 0.6885883),
#  (4, 0.99414164),
#  (6, 0.43300667),
#  (2, 0.9932848),
#  (5, 0.87241465),
#  (2, 0.7406729),
#  (1, 0.56860554),
#  (1, 0.99512565),
#  (6, 0.56663996),
#  (5, 0.8261437),
#  (3, 0.99878997),
#  (4, 0.5525126),
#  (6, 0.5904858),
#  (5, 0.9928852),
#  (2, 0.9218829),
#  (2, 0.8619957),
#  (1, 0.99074966),
#  (5, 0.88387877),
#  (4, 0.9956136),
#  (1, 0.6603315),
#  (5, 0.6665662),
#  (3, 0.7888801),
#  (4, 0.55845964),
#  (1, 0.513694),
#  (4, 0.95899034),
#  (6, 0.9903349),
#  (2, 0.76799405),
#  (5, 0.99569154),
#  (1, 0.8306561),
#  (4, 0.5547664),
#  (5, 0.99851984),
#  (5, 0.78392655),
#  (2, 0.85230637),
#  (5, 0.564741),
#  (3, 0.86316496),
#  (3, 0.31427833),
#  (6, 0.4306615),
#  (5, 0.82321584),
#  (6, 0.5031902),
#  (6, 0.48572138),
#  (4, 0.7356639),
#  (6, 0.39547616),
#  (2, 0.9909042),
#  (4, 0.44278416),
#  (6, 0.69107056),
#  (5, 0.46941358),
#  (4, 0.59246117),
#  (5, 0.9948208),
#  (3, 0.55105066),
#  (3, 0.9986794),
#  (5, 0.37510103),
#  (6, 0.41865966),
#  (5, 0.5693848),
#  (6, 0.58340126),
#  (5, 0.78780115),
#  (5, 0.8716161),
#  (6, 0.43857756),
#  (4, 0.9953826),
#  (6, 0.7780271),
#  (2, 0.62574077),
#  (2, 0.9944644),
#  (5, 0.8654205),
#  (1, 0.4971792),
#  (6, 0.49302125),
#  (5, 0.63957334),
#  (3, 0.9963688),
#  (3, 0.36853844),
#  (5, 0.95271254),
#  (1, 0.6604597),
#  (1, 0.55130446),
#  (5, 0.40920448),
#  (5, 0.45100072),
#  (5, 0.79056114),
#  (5, 0.99215835),
#  (2, 0.85879123),
#  (5, 0.99152267),
#  (2, 0.89474547),
#  (4, 0.99540323),
#  (3, 0.99609065),
#  (6, 0.84355295),
#  (1, 0.8265193),
#  (6, 0.96780366),
#  (6, 0.9678002),
#  (6, 0.9664558),
#  (6, 0.96637565),
#  (6, 0.96780336),
#  (6, 0.9664654),
#  (6, 0.9664657),
#  (6, 0.96641713),
#  (6, 0.96780115),
#  (6, 0.96779966),
#  (6, 0.96780366),
#  (2, 0.65580934),
#  (1, 0.992152),
#  (2, 0.99539727),
#  (5, 0.61911714),
#  (1, 0.9955777),
#  (2, 0.9969581),
#  (1, 0.6346377),
#  (5, 0.79863214),
#  (5, 0.6593341),
#  (6, 0.6088893),
#  (5, 0.51815903),
#  (5, 0.5001706),
#  (4, 0.9961262),
#  (1, 0.6026672),
#  (4, 0.51324606),
#  (5, 0.8051838),
#  (3, 0.99746555),
#  (2, 0.47371072),
#  (2, 0.8846849),
#  (4, 0.76054823),
#  (3, 0.99760866),
#  (6, 0.6118893),
#  (6, 0.51633245),
#  (6, 0.6290539),
#  (6, 0.4898503),
#  (1, 0.5843599),
#  (6, 0.4898759),
#  (6, 0.50759214),
#  (6, 0.5337617),
#  (2, 0.8264225),
#  (1, 0.52206117),
#  (1, 0.51289487),
#  (1, 0.5642346),
#  (6, 0.48926583),
#  (3, 0.99352056),
#  (1, 0.57533646),
#  (1, 0.64573395),
#  (1, 0.6049793),
#  (1, 0.53737056),
#  (1, 0.5373642),
#  (1, 0.61351454),
#  (5, 0.73942035),
#  (1, 0.6135122),
#  (5, 0.9925698),
#  (1, 0.5824914),
#  (3, 0.9931886),
#  (5, 0.9581926),
#  (4, 0.98598355),
#  (2, 0.805829),
#  (6, 0.79958767),
#  (2, 0.8998036),
#  (2, 0.9975806),
#  (3, 0.8998982),
#  (1, 0.6613171),
#  (4, 0.5432629),
#  (4, 0.45823717),
#  (2, 0.9824856),
#  (2, 0.81340307),
#  (1, 0.4580379),
#  (1, 0.6861783),
#  (4, 0.99326885),
#  (2, 0.5845392),
#  (1, 0.99065197),
#  (3, 0.9953047),
#  (2, 0.9946533),
#  (2, 0.8017225),
#  (3, 0.99527687),
#  (6, 0.78986335),
#  (3, 0.9591904),
#  (2, 0.96867234),
#  (3, 0.9973101),
#  (5, 0.99534816),
#  (1, 0.99064744),
#  (3, 0.9968572),
#  (2, 0.8689127),
#  (4, 0.99066234),
#  (4, 0.88267595),
#  (1, 0.64131284),
#  (2, 0.5108476),
#  (1, 0.9129509),
#  (3, 0.9973834),
#  (5, 0.6628666),
#  (3, 0.9908113),
#  (3, 0.9967468),
#  (2, 0.6298943),
#  (1, 0.99231464),
#  (3, 0.969968),
#  (3, 0.9967241),
#  (1, 0.9918553),
#  (1, 0.67826563),
#  (4, 0.8948381),
#  (3, 0.9907489),
#  (3, 0.9941489),
#  (5, 0.99394435),
#  (5, 0.99295026),
#  (4, 0.5503873),
#  (4, 0.992092),
#  (1, 0.83641595),
#  (1, 0.57588255),
#  (2, 0.50165236),
#  (3, 0.98997045),
#  (2, 0.6484987),
#  (6, 0.98649514),
#  (4, 0.9956348),
#  (3, 0.96897286),
#  (6, 0.7582211),
#  (6, 0.8405324),
#  (6, 0.99689925),
#  (4, 0.99414325),
#  (2, 0.9948037),
#  (3, 0.9948085),
#  (1, 0.99636596),
#  (2, 0.54567325),
#  (5, 0.9741724),
#  (5, 0.99722666),
#  (1, 0.69586813),
#  (1, 0.99429786),
#  (6, 0.74819744),
#  (2, 0.43343937),
#  (3, 0.9961216),
#  (2, 0.80724823),
#  (1, 0.99548274),
#  (5, 0.6213967),
#  (2, 0.8340842),
#  (4, 0.9967206),
#  (5, 0.59190905),
#  (1, 0.99080366),
#  (2, 0.5714008),
#  (2, 0.9945151),
#  (1, 0.99485624),
#  (2, 0.9927472),
#  (5, 0.9935454),
#  (5, 0.99315524),
#  (2, 0.5245478),
#  (2, 0.467807),
#  (2, 0.98572916),
#  (1, 0.6622133),
#  (1, 0.9926817),
#  (2, 0.9953474),
#  (5, 0.9825218),
#  (1, 0.9923731),
#  (4, 0.8530295),
#  (5, 0.982522),
#  (5, 0.9825228),
#  (4, 0.8705864),
#  (5, 0.9825228),
#  (5, 0.9825229),
#  (1, 0.9935464),
#  (5, 0.77321476),
#  (5, 0.9825229),
#  (4, 0.89113975),
#  (5, 0.9825229),
#  (4, 0.99354833),
#  (6, 0.54093206),
#  (5, 0.99458504),
#  (4, 0.90809387),
#  (5, 0.46568978),
#  (6, 0.9656649),
#  (4, 0.9946691),
#  (4, 0.88809025),
#  (5, 0.9825208),
#  (4, 0.83808166),
#  (5, 0.9825211),
#  (5, 0.84284604),
#  (5, 0.98252255),
#  (5, 0.98252296),
#  (5, 0.99544865),
#  (1, 0.99295026),
#  (6, 0.78501016),
#  (1, 0.9889773),
#  (2, 0.54594344),
#  (6, 0.5994486),
#  (6, 0.8904157),
#  (2, 0.9957221),
#  (1, 0.99386376),
#  (2, 0.9936874),
#  (4, 0.885578),
#  (1, 0.6134486),
#  (1, 0.62121683),
#  (1, 0.6213231),
#  (6, 0.54180664),
#  (1, 0.61346716),
#  (6, 0.5075543),
#  (2, 0.7080097),
#  (1, 0.5081737),
#  (1, 0.5076816),
#  (5, 0.99444425),
#  (1, 0.82490546),
#  (2, 0.505147),
#  (5, 0.5514245),
#  (1, 0.53857774),
#  (5, 0.9951696),
#  (2, 0.95151544),
#  (1, 0.99350995),
#  (6, 0.5048389),
#  (2, 0.997881),
#  (6, 0.57074714),
#  (2, 0.5233844),
#  (5, 0.7497101),
#  (1, 0.77724487),
#  (2, 0.731022),
#  (6, 0.9955178),
#  (2, 0.9467731),
#  (2, 0.62221146),
#  (1, 0.85220605),
#  (6, 0.7630785),
#  (1, 0.6563313),
#  (5, 0.9965038),
#  (2, 0.734258),
#  (4, 0.60242623),
#  (1, 0.90280944),
#  (4, 0.9688129),
#  (1, 0.8597838),
#  (1, 0.78354007),
#  (6, 0.9950116),
#  (6, 0.9942128),
#  (4, 0.9719446),
#  (2, 0.99500453),
#  (2, 0.9959098),
#  (2, 0.99485475),
#  (4, 0.6681567),
#  (5, 0.5761824),
#  (3, 0.95821595),
#  (1, 0.99037766),
#  (5, 0.7213297),
#  (6, 0.51270807),
#  (4, 0.368991),
#  (2, 0.89733434),
#  (5, 0.77907735),
#  (2, 0.9927787),
#  (2, 0.9228107),
#  (6, 0.64268124),
#  (5, 0.99160385),
#  (2, 0.99476504),
#  (5, 0.8519274),
#  (2, 0.6758208),
#  (4, 0.99187243),
#  (2, 0.9841866),
#  (2, 0.68611896),
#  (1, 0.99171025),
#  (1, 0.67486215),
#  (6, 0.9585925),
#  (5, 0.7529694),
#  (6, 0.99433184),
#  (1, 0.996062),
#  (2, 0.83093727),
#  (1, 0.8146568),
#  (5, 0.5964626),
#  (5, 0.507399),
#  (5, 0.45810765),
#  (2, 0.9937955),
#  (1, 0.9921004),
#  (6, 0.994983),
#  (1, 0.99573725),
#  (2, 0.99627143),
#  (6, 0.7237522),
#  (6, 0.9965357),
#  (6, 0.56070095),
#  (3, 0.99505514),
#  (1, 0.894084),
#  (2, 0.99622107),
#  (5, 0.58566153),
#  (4, 0.9944395),
#  (1, 0.54835445),
#  (2, 0.77494675),
#  (2, 0.9931785),
#  (2, 0.9956139),
#  (5, 0.4131167),
#  (1, 0.99245244),
#  (6, 0.727802),
#  (6, 0.9300725),
#  (1, 0.9923839),
#  (5, 0.7579337),
#  (1, 0.7122964),
#  (2, 0.9972314),
#  (5, 0.4619197),
#  (4, 0.99452865),
#  (1, 0.99089634),
#  (1, 0.67879444),
#  (4, 0.8581405),
#  (1, 0.9911898),
#  (1, 0.9967337),
#  (5, 0.9346077),
#  (1, 0.99318296),
#  (2, 0.51639146),
#  (1, 0.7677504),
#  (5, 0.5981153),
#  ...]

# %%
# 토픽과 점수 추가하여 df_merged로 합치기
df_score = pd.DataFrame(main_topic_list, columns=['토픽', '점수'])
df_merged = pd.concat([df_preprocess, df_score], axis=1)

# %%
# 높은 점수 순서대로 정렬한 후, 토픽으로 group을 생성한 후, 상위 5개씩 추출
df_merged = df_merged.drop_duplicates(subset=['제목'])
df_merged = df_merged.sort_values('점수', ascending=False)
df_result = df_merged.groupby('토픽').head(5)
df_result = df_result.sort_values('토픽', ignore_index=True)
df_result['토픽'] = df_result['토픽'].astype(int)
df_result = df_result[['URL', '토픽', '점수', '제목', '본문']]
# 최대 행 제한 해제
pd.set_option('display.max_rows', None)
# 최대 열 제한 해제
pd.set_option('display.max_columns', None)

df_result
# Out:
#                                                   URL  토픽        점수  \
# 0              https://v.daum.net/v/20230705112334243   1  0.996366
# 1   https://n.news.naver.com/mnews/article/003/001...   1  0.997196
# 2   https://n.news.naver.com/mnews/article/005/000...   1  0.997363
# 3   https://n.news.naver.com/mnews/article/014/000...   1  0.996587
# 4   https://n.news.naver.com/mnews/article/029/000...   1  0.997676
# 5   https://n.news.naver.com/mnews/article/028/000...   2  0.997195
# 6   https://n.news.naver.com/mnews/article/015/000...   2  0.997479
# 7   https://n.news.naver.com/mnews/article/018/000...   2  0.997624
# 8              https://v.daum.net/v/20230705104503023   2  0.997881
# 9   https://n.news.naver.com/mnews/article/018/000...   2  0.997771
# 10  https://n.news.naver.com/mnews/article/138/000...   3  0.997683
# 11  https://n.news.naver.com/mnews/article/003/001...   3  0.998772
# 12  https://n.news.naver.com/mnews/article/629/000...   3  0.998667
# 13  https://n.news.naver.com/mnews/article/003/001...   3  0.998136
# 14  https://n.news.naver.com/mnews/article/092/000...   3  0.998652
# 15  https://n.news.naver.com/mnews/article/023/000...   4  0.997889
# 16  https://n.news.naver.com/mnews/article/008/000...   4  0.997529
# 17  https://n.news.naver.com/mnews/article/008/000...   4  0.997508
# 18  https://n.news.naver.com/mnews/article/009/000...   4  0.998334
# 19  https://n.news.naver.com/mnews/article/023/000...   4  0.997688
# 20  https://n.news.naver.com/mnews/article/008/000...   5  0.997196
# 21  https://n.news.naver.com/mnews/article/629/000...   5  0.997202
# 22             https://v.daum.net/v/20230704173908934   5  0.997426
# 23             https://v.daum.net/v/20230704161201213   5  0.997546
# 24  https://n.news.naver.com/mnews/article/030/000...   5  0.998502
# 25             https://v.daum.net/v/20230704160015623   6  0.997376
# 26             https://v.daum.net/v/20230704155200283   6  0.997477
# 27  https://n.news.naver.com/mnews/article/018/000...   6  0.998087
# 28  https://n.news.naver.com/mnews/article/016/000...   6  0.996934
# 29  https://n.news.naver.com/mnews/article/366/000...   6  0.997601
#
#                                                    제목  \
# 0                KT스카이라이프, 'TV·모바일' 가족결합 20% 할인 상품 출시
# 1                   "무채색은 질려서?"…아이폰15·갤플립5 모두 원색에 꽂혔다
# 2                  생성형 AI, 광고 시장에 침투하다… “제작비 1/4로 줄어”
# 3                        KT스카이라이프, ‘20% 더블할인 가족결합’ 출시
# 4   [김나인의 `樂樂한 콘텐츠`] 100만명이 사랑한 AI 친구… 옷 골라주고 음악도 ...
# 5                생성형 인공지능, 46일 만에 신약 설계…사상 첫 임상 2상 진입
# 6   "AI로 내 사진 못 가져가"… 네이버가 찜한 스타트업 '큐빅' [허란의 VC 투자노트]
# 7              김용삼 진코어 대표 “세계 최고 수준 초소형 유전자가위 기술로 승부”
# 8                   SK바이오사이언스, 태국과 백신 개발·생산 인프라 구축 협력
# 9              [Bio다크호스-진코어편]②“초소형 유전자 가위 가치 상승여력 충분”
# 10                 野 안정상 “총선 대비 포털 장악” 비판…포털규제 법적근거는?
# 11           방통위, 수신료 분리징수 의결…졸속처리 vs KBS 방만경영 결과(종합)
# 12  방통위, 30년 만에 TV수신료·전기요금 분리…언론단체 "군사작전 같은 '묻지마 개정'"
# 13             로스트아크 '中 검열' 해명 나선 금강선 "고의 아냐…재발방지 약속"
# 14                전기요금 고지서에 KBS·EBS 수신료 빠진다...후폭풍 불가피
# 15             한국 바다에 삼중수소?… IAEA “日 방류 3㎞ 지나면 영향 없어”
# 16              '삼중수소' 못 거르는 설비…IAEA "방류 안전" 결론 내린 까닭
# 17               후쿠시마 오염수 방류 '초읽기'…"韓영향 미미" 과학계 주장 근거
# 18             “日 세슘우럭 먹게될거야” “연안 어류가 1000km 오는건 불가능”
# 19                           후쿠시마 방류 30년간 지속적 모니터링 계획
# 20              아이폰·워치로 中 점령...애플 '시총 5200조원' 향해 무한질주
# 21                 "바닥 찍고 반등 시작"…메모리 업황 개선에 삼성·SK 웃을까
# 22                              삼성, 국내 팹리스와 AI반도체 키운다
# 23                        삼성전자, 국내 팹리스와 손잡고 AI반도체 키운다
# 24                [스페셜리포트]미·중 무역전쟁 5년, K-제조 미래 혁신 갈림길
# 25                   "우주개발 속도 내려면 실패 경험 가진 선진국과 협력해야"
# 26                 '경영공백' 5개월만에 끝낸다...KT 새 CEO 7월말 윤곽
# 27                   KT, 차기 CEO 선임 돌입…AI 기업 '변신' 속도내나
# 28                             한국 ‘우주자원’ 개발 주도권 확보나선다
# 29       美 방산기업 ‘노스롭그루먼’ 부회장 “한국은 심각한 우주 안보 위기에 직면했다”
#
#                                                    본문
# 0   TV 모바일 회선 결합 최대 TV 할인 스카이라이프 모든 모바일 요금 결합 할인 혜...
# 1   아이폰 그니 크림슨 블루 그린 핑크 적용 플립 최대 크림 코랄 다이아몬드 기대 아이...
# 2   LG 유플러스 성형 AI 활용 영상 광고 론칭했다 영상 광고 성형 AI 아기 돼지 ...
# 3   KT 스카이라이프 가족 결합 대상 확대 요금 최대 할인 더블 할인 가족 결합 출시 ...
# 4   챗GPT 활용 사용자 맞춤 대화 프렌즈 말투 성격 달라 재미 쏠쏠 출시 개월 가입자...
# 5   리코 발성 섬유화 치료 제비 시간 단축 인공지능 설계 신약 후보 사상 음으로 시험 ...
# 6   이화여대 창업 스타트업 차등 정보보호 자체 개발 민감 정보 노출 위험 개인 합성 변...
# 7   코어 초소 유전자 가위 수출 성공 일부 질환 교정 전달 크리스 캐스 상회 추가 수출...
# 8   독감 백신 스카이 플루 완제 생산 이전 향후 중동 동남아 국가 사업 확장 예정 부족...
# 9   진화 세대 유전자 가위 플랫폼 AR 확보 크기 교정 성공 오프 타깃 마리 토끼 AR...
# 10  김효재 방송통신 위원장 직무 대행 지난달 정부 과천 청사 방송통신 위원회 전체 회의...
# 11  방통위 방송 시행 개정안 의결 수신료 납부 의무 여전 국회 공영 방송 이기 후속 조...
# 12  방통위 방송 시행 일부 개정 명령 사항 의결 입법 예고 기간 고작 열흘 언론 반발 ...
# 13  중국 검열 적용 논란 패치 실수 몬스터 현지 이슈 현지 인력 확충 재발 방지 금강 ...
# 14  방통위 시행 개정안 의결 정치 갈등 현장 혼란 가시 화지 부터 전기요금 통합 징수 ...
# 15  오염수 방류 국제 원자력 기구 최종 보고서 내면 후쿠시마 오염수 방류 현실 다가 전...
# 16  오염수 배출 기준 초과 핵종 제거 설비 SK 탱크 정화 안전성 문제 어도 해양 방류...
# 17  국제 원자력 기구 해양 방류 계획 점검 최종 보고서 발표 임박 오염수 방류 국내 해...
# 18  후쿠시마 오염수 괴담 팩트 체크 삼중수소 위험성 배출 기준 방류 과정 지속 감시 중...
# 19  오염수 농도 실시간 공유 총리 최종 보고서 전달 라파엘 로시 왼쪽 국제 원자력 기구...
# 20  애플 조달 돌파 점유 확장 주효 스마트폰 워치 위로 화웨이 바짝 추격 점령 MR 헤...
# 21  반도체 실적 풍향계 마이크론 예상 웃돈 실적 발표 가격 하락 낸드 플래시 정세 지난...
# 22  삼성전자 파운드리 포럼 파운드리 사업 육성 국내 팹리스 생태계 필요 판단 파운드리 ...
# 23  파운드리 사업 팹리스 고객 반도체 설계 필요 정보 내년 국내 팹리스 파운드리 불리 ...
# 24  미국 트럼프 정부 달러 규모 중국 상품 관세 부과 시작 무역 갈등 총성 전쟁 갈등 ...
# 25  서은숙 메릴랜드 인력 외국 협력 필요 조언 지질 자원 산학 기관 우주 자원 탐사 개...
# 26  대표이사 후보 공모 서치 주요 주주 추천 하순 최종 선출 오전 서울 종로구 KT 광...
# 27  신임 선임 마무리 목표 투명 성공 정성 확보 방안 마련 거대 AI 믿음 상용 투자 ...
# 28  지질 자원 연구원 산학 네트워크 구축 연구 역량 결집 우주 자원 탐사 개발 네트워크...
# 29  공군 우주 포럼 개최 트로이 노스롭 그루 부회장 발표 우주 안보 협력 강조 한국 변...

# %% [raw]
# # 원을 기준으로 숫자를 다시 넘버링
# topic_counts = {}
# for item in main_topic_list:
#     topic = item[0]
#     if topic in topic_counts:
#         topic_counts[topic] += 1
#     else:
#         topic_counts[topic] = 1
#
# print(topic_counts)
# data = {9: 103, 7: 186, 3: 55, 6: 93, 1: 81, 5: 60, 8: 106, 2: 125, 10: 141, 4: 204}
# sorted_data = sorted(data.items(), key=lambda x: x[1], reverse=True)
# print(sorted_data)

# %% [raw]
# # 토픽 별 결과 확인
# display(df_result[df_result['토픽']==1])
# display(df_result[df_result['토픽']==2])
# display(df_result[df_result['토픽']==3])

# %% [markdown]
# # 확인한 결과에서, 메일에 사용할 기사만 추출

# %%
select_topic = input('사용할 토픽을 입력하세요')
select_topic = select_topic.split(' ')

naming = input('순서대로 토픽의 키워드를 명명하세요.')
naming = naming.split(' ')

cond1 = (df_result['토픽']==int(select_topic[0]))
cond2 = (df_result['토픽']==int(select_topic[1]))
cond3 = (df_result['토픽']==int(select_topic[2]))

df_result = df_result[cond1|cond2|cond3]

topic_num, topic_keywords = [int(select_topic[0]), int(select_topic[1]), int(select_topic[2])], [naming[0], naming[1], naming[2]]
df_result.loc[df_result['토픽'].isin(topic_num), '토픽'] = df_result['토픽'].map(dict(zip(topic_num, topic_keywords)))
df_result
# Out:
# 사용할 토픽을 입력하세요3 4 6
# 순서대로 토픽의 키워드를 명명하세요.KBS IAEA 우주산업
#                                                   URL    토픽        점수  \
# 10  https://n.news.naver.com/mnews/article/138/000...   KBS  0.997683
# 11  https://n.news.naver.com/mnews/article/003/001...   KBS  0.998772
# 12  https://n.news.naver.com/mnews/article/629/000...   KBS  0.998667
# 13  https://n.news.naver.com/mnews/article/003/001...   KBS  0.998136
# 14  https://n.news.naver.com/mnews/article/092/000...   KBS  0.998652
# 15  https://n.news.naver.com/mnews/article/023/000...  IAEA  0.997889
# 16  https://n.news.naver.com/mnews/article/008/000...  IAEA  0.997529
# 17  https://n.news.naver.com/mnews/article/008/000...  IAEA  0.997508
# 18  https://n.news.naver.com/mnews/article/009/000...  IAEA  0.998334
# 19  https://n.news.naver.com/mnews/article/023/000...  IAEA  0.997688
# 25             https://v.daum.net/v/20230704160015623  우주산업  0.997376
# 26             https://v.daum.net/v/20230704155200283  우주산업  0.997477
# 27  https://n.news.naver.com/mnews/article/018/000...  우주산업  0.998087
# 28  https://n.news.naver.com/mnews/article/016/000...  우주산업  0.996934
# 29  https://n.news.naver.com/mnews/article/366/000...  우주산업  0.997601
#
#                                                    제목  \
# 10                 野 안정상 “총선 대비 포털 장악” 비판…포털규제 법적근거는?
# 11           방통위, 수신료 분리징수 의결…졸속처리 vs KBS 방만경영 결과(종합)
# 12  방통위, 30년 만에 TV수신료·전기요금 분리…언론단체 "군사작전 같은 '묻지마 개정'"
# 13             로스트아크 '中 검열' 해명 나선 금강선 "고의 아냐…재발방지 약속"
# 14                전기요금 고지서에 KBS·EBS 수신료 빠진다...후폭풍 불가피
# 15             한국 바다에 삼중수소?… IAEA “日 방류 3㎞ 지나면 영향 없어”
# 16              '삼중수소' 못 거르는 설비…IAEA "방류 안전" 결론 내린 까닭
# 17               후쿠시마 오염수 방류 '초읽기'…"韓영향 미미" 과학계 주장 근거
# 18             “日 세슘우럭 먹게될거야” “연안 어류가 1000km 오는건 불가능”
# 19                           후쿠시마 방류 30년간 지속적 모니터링 계획
# 25                   "우주개발 속도 내려면 실패 경험 가진 선진국과 협력해야"
# 26                 '경영공백' 5개월만에 끝낸다...KT 새 CEO 7월말 윤곽
# 27                   KT, 차기 CEO 선임 돌입…AI 기업 '변신' 속도내나
# 28                             한국 ‘우주자원’ 개발 주도권 확보나선다
# 29       美 방산기업 ‘노스롭그루먼’ 부회장 “한국은 심각한 우주 안보 위기에 직면했다”
#
#                                                    본문
# 10  김효재 방송통신 위원장 직무 대행 지난달 정부 과천 청사 방송통신 위원회 전체 회의...
# 11  방통위 방송 시행 개정안 의결 수신료 납부 의무 여전 국회 공영 방송 이기 후속 조...
# 12  방통위 방송 시행 일부 개정 명령 사항 의결 입법 예고 기간 고작 열흘 언론 반발 ...
# 13  중국 검열 적용 논란 패치 실수 몬스터 현지 이슈 현지 인력 확충 재발 방지 금강 ...
# 14  방통위 시행 개정안 의결 정치 갈등 현장 혼란 가시 화지 부터 전기요금 통합 징수 ...
# 15  오염수 방류 국제 원자력 기구 최종 보고서 내면 후쿠시마 오염수 방류 현실 다가 전...
# 16  오염수 배출 기준 초과 핵종 제거 설비 SK 탱크 정화 안전성 문제 어도 해양 방류...
# 17  국제 원자력 기구 해양 방류 계획 점검 최종 보고서 발표 임박 오염수 방류 국내 해...
# 18  후쿠시마 오염수 괴담 팩트 체크 삼중수소 위험성 배출 기준 방류 과정 지속 감시 중...
# 19  오염수 농도 실시간 공유 총리 최종 보고서 전달 라파엘 로시 왼쪽 국제 원자력 기구...
# 25  서은숙 메릴랜드 인력 외국 협력 필요 조언 지질 자원 산학 기관 우주 자원 탐사 개...
# 26  대표이사 후보 공모 서치 주요 주주 추천 하순 최종 선출 오전 서울 종로구 KT 광...
# 27  신임 선임 마무리 목표 투명 성공 정성 확보 방안 마련 거대 AI 믿음 상용 투자 ...
# 28  지질 자원 연구원 산학 네트워크 구축 연구 역량 결집 우주 자원 탐사 개발 네트워크...
# 29  공군 우주 포럼 개최 트로이 노스롭 그루 부회장 발표 우주 안보 협력 강조 한국 변...

# %% [markdown]
# # 메일링 형식으로 데이터프레임 가공 (+ 기사요약)

# %%
# Inner Join으로 본문 컬럼 다시 가져와 추가
df_final = pd.merge(df_result, df[['URL', '본문']], on='URL', how='inner')

# 컬럼명 재설정
df_final = df_final.rename(columns={'본문_x':'본문', '본문_y':'원본', 'URL':'link', '제목':'title', '토픽':'topic'})
df_final = df_final.rename(columns={'본문':'wc'})

# 빈 요약 컬럼 추가
df_final['desc'] = np.nan

# 가독성을 위해 순서 변경
df_final = df_final[['topic', 'link', 'wc', 'desc', '원본', 'title']]

# 네이버 클로바를 이용한 요약 추가
df_final['desc'] = df_final['원본'].apply(temp_summarize_text)

# 본문 요약에 사용한 원본 컬럼 삭제
df_final = df_final.drop(columns=['원본'])

df_final
# Out:
#    topic                                               link  \
# 0    KBS  https://n.news.naver.com/mnews/article/138/000...
# 1    KBS  https://n.news.naver.com/mnews/article/003/001...
# 2    KBS  https://n.news.naver.com/mnews/article/629/000...
# 3    KBS  https://n.news.naver.com/mnews/article/003/001...
# 4    KBS  https://n.news.naver.com/mnews/article/092/000...
# 5   IAEA  https://n.news.naver.com/mnews/article/023/000...
# 6   IAEA  https://n.news.naver.com/mnews/article/008/000...
# 7   IAEA  https://n.news.naver.com/mnews/article/008/000...
# 8   IAEA  https://n.news.naver.com/mnews/article/009/000...
# 9   IAEA  https://n.news.naver.com/mnews/article/023/000...
# 10  우주산업             https://v.daum.net/v/20230704160015623
# 11  우주산업             https://v.daum.net/v/20230704155200283
# 12  우주산업  https://n.news.naver.com/mnews/article/018/000...
# 13  우주산업  https://n.news.naver.com/mnews/article/016/000...
# 14  우주산업  https://n.news.naver.com/mnews/article/366/000...
#
#                                                    wc  \
# 0   김효재 방송통신 위원장 직무 대행 지난달 정부 과천 청사 방송통신 위원회 전체 회의...
# 1   방통위 방송 시행 개정안 의결 수신료 납부 의무 여전 국회 공영 방송 이기 후속 조...
# 2   방통위 방송 시행 일부 개정 명령 사항 의결 입법 예고 기간 고작 열흘 언론 반발 ...
# 3   중국 검열 적용 논란 패치 실수 몬스터 현지 이슈 현지 인력 확충 재발 방지 금강 ...
# 4   방통위 시행 개정안 의결 정치 갈등 현장 혼란 가시 화지 부터 전기요금 통합 징수 ...
# 5   오염수 방류 국제 원자력 기구 최종 보고서 내면 후쿠시마 오염수 방류 현실 다가 전...
# 6   오염수 배출 기준 초과 핵종 제거 설비 SK 탱크 정화 안전성 문제 어도 해양 방류...
# 7   국제 원자력 기구 해양 방류 계획 점검 최종 보고서 발표 임박 오염수 방류 국내 해...
# 8   후쿠시마 오염수 괴담 팩트 체크 삼중수소 위험성 배출 기준 방류 과정 지속 감시 중...
# 9   오염수 농도 실시간 공유 총리 최종 보고서 전달 라파엘 로시 왼쪽 국제 원자력 기구...
# 10  서은숙 메릴랜드 인력 외국 협력 필요 조언 지질 자원 산학 기관 우주 자원 탐사 개...
# 11  대표이사 후보 공모 서치 주요 주주 추천 하순 최종 선출 오전 서울 종로구 KT 광...
# 12  신임 선임 마무리 목표 투명 성공 정성 확보 방안 마련 거대 AI 믿음 상용 투자 ...
# 13  지질 자원 연구원 산학 네트워크 구축 연구 역량 결집 우주 자원 탐사 개발 네트워크...
# 14  공군 우주 포럼 개최 트로이 노스롭 그루 부회장 발표 우주 안보 협력 강조 한국 변...
#
#                                                  desc  \
# 0   안 수석전문위원은 여당과 보수언론이 근거도 없이 네이버를 부당하게 공격하고 비판하자...
# 1   방송통신위원회가 5일 전체회의에서 KBS 수신료 분리징수를 위한 방송법 시행령 개정...
# 2   KBS·언론계 반발이르면 이달 중순부터 시행방송통신위원회가 5일 정부 과천청사에서 ...
# 3   금강선, 총괄디렉터 임시복귀해 소통 집중금강선 스마일게이트RPG 본부장은 4일 밤 ...
# 4   5일 방통위는 전체회의를 열고 TV수신료를 징수 수탁 사업자의 고유 업무와 결합해 ...
# 5   IAEA는 ALPS로 처리한 오염수에 100배에 달하는 해수를 섞어 희석 후 방출할...
# 6   오염수 현재 약 130만톤 중 90만톤 배출기준치 초과다핵종제거설비(ALPS)·K4...
# 7   IAEA(국제원자력기구) 해양방류 계획 점검한 최종보고서 발표 임박日오염수 방류로 ...
# 8   2019년 이전 저장수 주목韓정부, 방사능 조사지점 현재 92개에서 200개로 확대...
# 9   라파엘 그로시(왼쪽) 국제원자력기구(IAEA) 사무총장이 4일 일본 도쿄의 총리 관...
# 10  서은숙 메릴랜드대 교수, 인력 등 외국과 협력 필요 조언지질자원연, 산학연 40개 ...
# 11  KT 이사회는 대표이사 후보군 구성 과정에서 외부 전문기관(서치펌)의 추천과 함께 ...
# 12  KT는 3일 사외이사 전원으로 구성된 이사후보추천위원회에서 대표이사 후보군 구성 방...
# 13  이번 포럼에는 코오롱·한화에어로스페이스, 고려대·인하대, 한국원자력연구원 등 우주자...
# 14  공군, 2023 열린우주포럼 개최트로이 브래쉬어 노스롭그루먼 부회장 발표우주 안보에...
#
#                                                 title
# 0                  野 안정상 “총선 대비 포털 장악” 비판…포털규제 법적근거는?
# 1            방통위, 수신료 분리징수 의결…졸속처리 vs KBS 방만경영 결과(종합)
# 2   방통위, 30년 만에 TV수신료·전기요금 분리…언론단체 "군사작전 같은 '묻지마 개정'"
# 3              로스트아크 '中 검열' 해명 나선 금강선 "고의 아냐…재발방지 약속"
# 4                 전기요금 고지서에 KBS·EBS 수신료 빠진다...후폭풍 불가피
# 5              한국 바다에 삼중수소?… IAEA “日 방류 3㎞ 지나면 영향 없어”
# 6               '삼중수소' 못 거르는 설비…IAEA "방류 안전" 결론 내린 까닭
# 7                후쿠시마 오염수 방류 '초읽기'…"韓영향 미미" 과학계 주장 근거
# 8              “日 세슘우럭 먹게될거야” “연안 어류가 1000km 오는건 불가능”
# 9                            후쿠시마 방류 30년간 지속적 모니터링 계획
# 10                   "우주개발 속도 내려면 실패 경험 가진 선진국과 협력해야"
# 11                 '경영공백' 5개월만에 끝낸다...KT 새 CEO 7월말 윤곽
# 12                   KT, 차기 CEO 선임 돌입…AI 기업 '변신' 속도내나
# 13                             한국 ‘우주자원’ 개발 주도권 확보나선다
# 14       美 방산기업 ‘노스롭그루먼’ 부회장 “한국은 심각한 우주 안보 위기에 직면했다”

# %% [markdown]
# # 워드클라우드 생성 및 wordclouds 폴더에 저장

# %%
# 설정
width = 580
height = 338
max_words=30
mask = cv2.imread('./image/circle.png')
mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)

# 시간 포맷
now = datetime.now()
formatted_time = now.strftime("%Y-%m-%d_%p")
formatted_time = formatted_time.lower()

# 각 토픽마다 WC 생성 후 저장
for name in naming:
    text = ' '.join(df_final[df_final['topic']==name]['wc'])
    wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf', width=width, height=height, max_words=max_words,
                          background_color='white', collocations=False, prefer_horizontal=1, mask=mask).generate(text)
    image = wordcloud.to_image()
    image.save('./wordclouds/'+formatted_time+'_'+name+'.jpg')

# %% [markdown]
# # git push 후, 데이터 프레임에 추가

# %% [markdown]
# **github에 워드클라우드 업로드**
# - git add .
# - git commit -m 'upload wordclouds'
# - git push

# %%
# 깃허브에서 다시 받아오기
wc1 = 'https://github.com/jinn0135/DA28_final_PagePalette/blob/main/news/wordclouds/' + formatted_time+'_'+quote(naming[0])+ '.jpg?raw=true'
wc2 = 'https://github.com/jinn0135/DA28_final_PagePalette/blob/main/news/wordclouds/' + formatted_time+'_'+quote(naming[1])+ '.jpg?raw=true'
wc3 = 'https://github.com/jinn0135/DA28_final_PagePalette/blob/main/news/wordclouds/' + formatted_time+'_'+quote(naming[2])+ '.jpg?raw=true'
temp1 = df_final[df_final['topic']==naming[0]]
temp1['wc'] = wc1

temp2 = df_final[df_final['topic']==naming[1]]
temp2['wc'] = wc2

temp3 = df_final[df_final['topic']==naming[2]]
temp3['wc'] = wc3
# Out:
# C:\Users\kyooo\AppData\Local\Temp\ipykernel_3768\1252726757.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp1['wc'] = wc1
# C:\Users\kyooo\AppData\Local\Temp\ipykernel_3768\1252726757.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp2['wc'] = wc2
# C:\Users\kyooo\AppData\Local\Temp\ipykernel_3768\1252726757.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp3['wc'] = wc3

# %%
df_prepared = pd.concat([temp1, temp2, temp3])
df_prepared
# Out:
#    topic                                               link  \
# 0    KBS  https://n.news.naver.com/mnews/article/138/000...
# 1    KBS  https://n.news.naver.com/mnews/article/003/001...
# 2    KBS  https://n.news.naver.com/mnews/article/629/000...
# 3    KBS  https://n.news.naver.com/mnews/article/003/001...
# 4    KBS  https://n.news.naver.com/mnews/article/092/000...
# 5   IAEA  https://n.news.naver.com/mnews/article/023/000...
# 6   IAEA  https://n.news.naver.com/mnews/article/008/000...
# 7   IAEA  https://n.news.naver.com/mnews/article/008/000...
# 8   IAEA  https://n.news.naver.com/mnews/article/009/000...
# 9   IAEA  https://n.news.naver.com/mnews/article/023/000...
# 10  우주산업             https://v.daum.net/v/20230704160015623
# 11  우주산업             https://v.daum.net/v/20230704155200283
# 12  우주산업  https://n.news.naver.com/mnews/article/018/000...
# 13  우주산업  https://n.news.naver.com/mnews/article/016/000...
# 14  우주산업  https://n.news.naver.com/mnews/article/366/000...
#
#                                                    wc  \
# 0   https://github.com/jinn0135/DA28_final_PagePal...
# 1   https://github.com/jinn0135/DA28_final_PagePal...
# 2   https://github.com/jinn0135/DA28_final_PagePal...
# 3   https://github.com/jinn0135/DA28_final_PagePal...
# 4   https://github.com/jinn0135/DA28_final_PagePal...
# 5   https://github.com/jinn0135/DA28_final_PagePal...
# 6   https://github.com/jinn0135/DA28_final_PagePal...
# 7   https://github.com/jinn0135/DA28_final_PagePal...
# 8   https://github.com/jinn0135/DA28_final_PagePal...
# 9   https://github.com/jinn0135/DA28_final_PagePal...
# 10  https://github.com/jinn0135/DA28_final_PagePal...
# 11  https://github.com/jinn0135/DA28_final_PagePal...
# 12  https://github.com/jinn0135/DA28_final_PagePal...
# 13  https://github.com/jinn0135/DA28_final_PagePal...
# 14  https://github.com/jinn0135/DA28_final_PagePal...
#
#                                                  desc  \
# 0   안 수석전문위원은 여당과 보수언론이 근거도 없이 네이버를 부당하게 공격하고 비판하자...
# 1   방송통신위원회가 5일 전체회의에서 KBS 수신료 분리징수를 위한 방송법 시행령 개정...
# 2   KBS·언론계 반발이르면 이달 중순부터 시행방송통신위원회가 5일 정부 과천청사에서 ...
# 3   금강선, 총괄디렉터 임시복귀해 소통 집중금강선 스마일게이트RPG 본부장은 4일 밤 ...
# 4   5일 방통위는 전체회의를 열고 TV수신료를 징수 수탁 사업자의 고유 업무와 결합해 ...
# 5   IAEA는 ALPS로 처리한 오염수에 100배에 달하는 해수를 섞어 희석 후 방출할...
# 6   오염수 현재 약 130만톤 중 90만톤 배출기준치 초과다핵종제거설비(ALPS)·K4...
# 7   IAEA(국제원자력기구) 해양방류 계획 점검한 최종보고서 발표 임박日오염수 방류로 ...
# 8   2019년 이전 저장수 주목韓정부, 방사능 조사지점 현재 92개에서 200개로 확대...
# 9   라파엘 그로시(왼쪽) 국제원자력기구(IAEA) 사무총장이 4일 일본 도쿄의 총리 관...
# 10  서은숙 메릴랜드대 교수, 인력 등 외국과 협력 필요 조언지질자원연, 산학연 40개 ...
# 11  KT 이사회는 대표이사 후보군 구성 과정에서 외부 전문기관(서치펌)의 추천과 함께 ...
# 12  KT는 3일 사외이사 전원으로 구성된 이사후보추천위원회에서 대표이사 후보군 구성 방...
# 13  이번 포럼에는 코오롱·한화에어로스페이스, 고려대·인하대, 한국원자력연구원 등 우주자...
# 14  공군, 2023 열린우주포럼 개최트로이 브래쉬어 노스롭그루먼 부회장 발표우주 안보에...
#
#                                                 title
# 0                  野 안정상 “총선 대비 포털 장악” 비판…포털규제 법적근거는?
# 1            방통위, 수신료 분리징수 의결…졸속처리 vs KBS 방만경영 결과(종합)
# 2   방통위, 30년 만에 TV수신료·전기요금 분리…언론단체 "군사작전 같은 '묻지마 개정'"
# 3              로스트아크 '中 검열' 해명 나선 금강선 "고의 아냐…재발방지 약속"
# 4                 전기요금 고지서에 KBS·EBS 수신료 빠진다...후폭풍 불가피
# 5              한국 바다에 삼중수소?… IAEA “日 방류 3㎞ 지나면 영향 없어”
# 6               '삼중수소' 못 거르는 설비…IAEA "방류 안전" 결론 내린 까닭
# 7                후쿠시마 오염수 방류 '초읽기'…"韓영향 미미" 과학계 주장 근거
# 8              “日 세슘우럭 먹게될거야” “연안 어류가 1000km 오는건 불가능”
# 9                            후쿠시마 방류 30년간 지속적 모니터링 계획
# 10                   "우주개발 속도 내려면 실패 경험 가진 선진국과 협력해야"
# 11                 '경영공백' 5개월만에 끝낸다...KT 새 CEO 7월말 윤곽
# 12                   KT, 차기 CEO 선임 돌입…AI 기업 '변신' 속도내나
# 13                             한국 ‘우주자원’ 개발 주도권 확보나선다
# 14       美 방산기업 ‘노스롭그루먼’ 부회장 “한국은 심각한 우주 안보 위기에 직면했다”

# %% [markdown]
# # data 폴더에 저장

# %%
df_prepared.to_csv('./data/' + formatted_time + '.csv', index=False)

# %% [markdown]
# **git push 필요**
