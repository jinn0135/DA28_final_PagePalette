# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
from news_utils import read_csv_file
from news_crawling import news_crawler
from datetime import datetime

import warnings # FutureWarning 안보이게
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %% [markdown]
# # URL 리스트 받아오기

# %%
url_list = read_csv_file()
url_list[:7]
# Out:
# urls_230627.csv 로부터 csv파일 불러오기 성공
# 총 URL 수 : 614
# ['https://n.news.naver.com/mnews/article/277/0005278112?sid=105',
#  'https://n.news.naver.com/mnews/article/016/0002161187?sid=105',
#  'https://n.news.naver.com/mnews/article/018/0005517677?sid=105',
#  'https://n.news.naver.com/mnews/article/008/0004904448?sid=105',
#  'https://n.news.naver.com/mnews/article/030/0003111580?sid=105',
#  'https://n.news.naver.com/mnews/article/421/0006890894?sid=105',
#  'https://n.news.naver.com/mnews/article/008/0004904397?sid=105']

# %%
df = pd.DataFrame({'URL':url_list, '신문사':np.nan, '기자명':np.nan, '제목':np.nan, '본문':np.nan,
                   '날짜':np.nan, '연':np.nan, '월':np.nan, '일':np.nan, '요일':np.nan})
df
# Out:
#                                                    URL  신문사  기자명  제목  본문  날짜  \
# 0    https://n.news.naver.com/mnews/article/277/000...  NaN  NaN NaN NaN NaN
# 1    https://n.news.naver.com/mnews/article/016/000...  NaN  NaN NaN NaN NaN
# 2    https://n.news.naver.com/mnews/article/018/000...  NaN  NaN NaN NaN NaN
# 3    https://n.news.naver.com/mnews/article/008/000...  NaN  NaN NaN NaN NaN
# 4    https://n.news.naver.com/mnews/article/030/000...  NaN  NaN NaN NaN NaN
# ..                                                 ...  ...  ...  ..  ..  ..
# 609  https://n.news.naver.com/mnews/article/008/000...  NaN  NaN NaN NaN NaN
# 610  https://n.news.naver.com/mnews/article/031/000...  NaN  NaN NaN NaN NaN
# 611  https://n.news.naver.com/mnews/article/056/001...  NaN  NaN NaN NaN NaN
# 612  https://n.news.naver.com/mnews/article/092/000...  NaN  NaN NaN NaN NaN
# 613  https://n.news.naver.com/mnews/article/018/000...  NaN  NaN NaN NaN NaN
#
#       연   월   일  요일
# 0   NaN NaN NaN NaN
# ...

# %% [markdown]
# # 필요한 정보 스크래핑 하여 df에적재 및 df_yymmdd.csv로저장

# %%
df = news_crawler(df)
# Out:
# 100%|██████████| 614/614 [08:45<00:00,  1.17it/s]

# %%
today = datetime.today().strftime('%y%m%d')
df.to_csv('df_'+today+'.csv', index=False)

display(df.head(3))
display(df.tail(3))
# Out:
#                                                  URL    신문사  기자명  \
# 0  https://n.news.naver.com/mnews/article/277/000...  아시아경제  오수연
# 1  https://n.news.naver.com/mnews/article/016/000...  헤럴드경제  김현일
# 2  https://n.news.naver.com/mnews/article/018/000...   이데일리  함정선
#
#                                      제목  \
# 0         KT클라우드, '클라우드 기반 NPU 인프라' 상용화
# 1      네이버·카카오로도 SRT 승차권 예매·자동차 검사 예약한다
# 2  SKT, 청년요금제 인기…신규·변경 고객 10명 중 7명 '선택'
#
#                                                   본문         날짜     연  월   일  \
# 0  초거대 인공지능(AI) 연구?개발을 위한 AI 반도체 인프라를 온라인 전용 포털에서... 2023-06-27  2023  6  27
# 1  네이버 지도 앱(왼쪽)과 카카오 T 앱에서 SRT 예매하는 화면. [디지털플랫폼정부... 2023-06-26  2023  6  26
# 2  만 19~34세 5G로 변경 청년 고객 73% 가입\n연말까지 가입자 100만명 목... 2023-06-27  2023  6  27
#
#    요일
# 0   1
# 1   0
# 2   1
#                                                    URL          신문사  기자명  \
# 205  https://n.news.naver.com/mnews/article/092/000...  ZDNet Korea  조성진
# ...
